# %% [markdown]
# ## The Hangman Game

# %% [markdown]
# The <a href="https://en.wikipedia.org/wiki/Hangman_(game)">Hangman game</a> is a simple game whereby one person thinks of a word, which they keep secret from their opponent, who tries to guess the word one character at a time. The game ends when the opponent makes more than a fixed number of incorrect guesses, or they figure out the secret word before then (in which case they *win*).
#
# Here's a simple version of the game, and a method allowing interactive play.
#
#
# The descruiption and the methods **`hangman`** and **`human`** is obtained from University of Melbourne, from the course [Web Search and Text Analysis](http://people.eng.unimelb.edu.au/tcohn/comp90042.html)

# %%
# allowing better python 2 & python 3 compatibility 
from __future__ import print_function 

def hangman(secret_word, guesser, max_mistakes=8, verbose=True):
    secret_word = secret_word.lower()
    mask = ['_'] * len(secret_word)
    guessed = set()
    if verbose:
        print("Starting hangman game. Target is", ' '.join(mask), 'length', len(secret_word))
    
    mistakes = 0
    while mistakes < max_mistakes:
        if verbose:
            print("You have", (max_mistakes-mistakes), "attempts remaining.")
        guess = guesser(mask, guessed)

        if verbose:
            print('Guess is', guess)
        if guess in guessed:
            if verbose:
                print('Already guessed this before.')
            mistakes += 1
        else:
            guessed.add(guess)
            if guess in secret_word:
                for i, c in enumerate(secret_word):
                    if c == guess:
                        mask[i] = c
                if verbose:
                    print('Good guess:', ' '.join(mask))
            else:
                if verbose:
                    print('Sorry, try again.')
                mistakes += 1
                
        if '_' not in mask:
            if verbose:
                print('Congratulations, you won.')
            return mistakes
        
    if verbose:
        print('Out of guesses. The word was', secret_word)    
    return mistakes

def human(mask, guessed):
    print('Enter your guess:')
    return input().lower().strip()
    #return input().lower().strip() # swap with above for python 3

# %%
hangman('whatever', human, 8, True)
# Out:
# Starting hangman game. Target is _ _ _ _ _ _ _ _ length 8
# You have 8 attempts remaining.
# Enter your guess:
# a
# Guess is a
# Good guess: _ _ a _ _ _ _ _
# You have 8 attempts remaining.
# Enter your guess:
# w
# Guess is w
# Good guess: w _ a _ _ _ _ _
# You have 8 attempts remaining.
# Enter your guess:
# e
# Guess is e
# Good guess: w _ a _ e _ e _
# You have 8 attempts remaining.
# Enter your guess:
# h
# Guess is h
# Good guess: w h a _ e _ e _
# You have 8 attempts remaining.
# Enter your guess:
# k
# Guess is k
# Sorry, try again.
# You have 7 attempts remaining.
# Enter your guess:
# q
# Guess is q
# Sorry, try again.
# You have 6 attempts remaining.
# Enter your guess:
# a
# Guess is a
# Already guessed this before.
# You have 5 attempts remaining.
# Enter your guess:
# l
# Guess is l
# Sorry, try again.
# You have 4 attempts remaining.
# Enter your guess:
# r
# Guess is r
# Good guess: w h a _ e _ e r
# You have 4 attempts remaining.
# Enter your guess:
# s
# Guess is s
# Sorry, try again.
# You have 3 attempts remaining.
# Enter your guess:
# f
# Guess is f
# Sorry, try again.
# You have 2 attempts remaining.
# Enter your guess:
# t
# Guess is t
# Good guess: w h a t e _ e r
# You have 2 attempts remaining.
# Enter your guess:
# v
# Guess is v
# Good guess: w h a t e v e r
# Congratulations, you won.
# 6

# %% [markdown]
# ## Loading the dataset

# %%
f = open('corncob_lowercase.txt').read().splitlines()
f[:50]
# Out:
# ['aardvark',
#  'aardwolf',
#  'aaron',
#  'aback',
#  'abacus',
#  'abaft',
#  'abalone',
#  'abandon',
#  'abandoned',
#  'abandonment',
#  'abandons',
#  'abase',
#  'abased',
#  'abasement',
#  'abash',
#  'abashed',
#  'abate',
#  'abated',
#  'abatement',
#  'abates',
#  'abattoir',
#  'abattoirs',
#  'abbe',
#  'abbess',
#  'abbey',
#  'abbeys',
#  'abbot',
#  'abbots',
#  'abbreviate',
#  'abbreviated',
#  'abbreviates',
#  'abbreviating',
#  'abbreviation',
#  'abbreviations',
#  'abdicate',
#  'abdicated',
#  'abdicates',
#  'abdicating',
#  'abdication',
#  'abdomen',
#  'abdomens',
#  'abdominal',
#  'abduct',
#  'abducted',
#  'abducting',
#  'abduction',
#  'abductions',
#  'abductor',
#  'abductors',
#  'abducts']

# %%
test = set()
for i,item in enumerate(f):
    if i%58 == 0:
        test.add(item)
        
train = set(f) - test

len(train), len(test)
# Out:
# (57107, 1002)

# %% [markdown]
# ## Randomly predicting a character at a time

# %%
import numpy as np
import string    



def randomG(mask,guessed):
    
    # Initialise a dictionary with all the charcters in the alphbet
    d = dict.fromkeys(string.ascii_lowercase, 0)
    
    # Give an integer index for each character
    pd = dict()
    for i,j in enumerate(d.keys()):
        pd[i+1] = j
    
    while 1:
        trials = np.random.choice(range(1,27), 1,replace=False)
        if trials[0] not in guessed:
            return pd[trials[0]]

# %%
mist = hangman('whatever',randomG,8)
# Out:
# Starting hangman game. Target is _ _ _ _ _ _ _ _ length 8
# You have 8 attempts remaining.
# Guess is l
# Sorry, try again.
# You have 7 attempts remaining.
# Guess is g
# Sorry, try again.
# You have 6 attempts remaining.
# Guess is g
# Already guessed this before.
# You have 5 attempts remaining.
# Guess is z
# Sorry, try again.
# You have 4 attempts remaining.
# Guess is t
# Good guess: _ _ _ t _ _ _ _
# You have 4 attempts remaining.
# Guess is z
# Already guessed this before.
# You have 3 attempts remaining.
# Guess is t
# Already guessed this before.
# You have 2 attempts remaining.
# Guess is a
# Good guess: _ _ a t _ _ _ _
# You have 2 attempts remaining.
# Guess is y
# Sorry, try again.
# You have 1 attempts remaining.
# Guess is l
# Already guessed this before.
# Out of guesses. The word was whatever

# %%
# Number of mistakes made in count of characters - Highest possible for 1002 words?
totMist = 0


# Number of words correctly predicted?
corrs = 0

#Testing fo
for i,item in enumerate(test):
    mist = hangman(item, randomG, 8, False)
    totMist += mist
    if mist < 8:
        corrs += 1
        print(i,item)

print(totMist,corrs)
# Out:
# 289 agape
# 927 gamut
# 8009 2

# %% [markdown]
# ## Unigram character prediction

# %%
charaFreq = dict()
totFreq = 0
for item in train:
    for chara in item:
        try:
            charaFreq[chara] += 1
        except:
            charaFreq[chara] = 1            
        totFreq += 1
import operator
sorted_x = sorted(charaFreq.items(), key=operator.itemgetter(1),reverse=True)

sorted_x
# Out:
# [('e', 55036),
#  ('i', 41882),
#  ('s', 40717),
#  ('a', 36017),
#  ('r', 34582),
#  ('n', 33881),
#  ('t', 33360),
#  ('o', 28549),
#  ('l', 25936),
#  ('c', 19565),
#  ('d', 19028),
#  ('u', 16230),
#  ('g', 14060),
#  ('p', 13883),
#  ('m', 12720),
#  ('h', 10221),
#  ('b', 8880),
#  ('y', 8210),
#  ('f', 6761),
#  ('v', 5043),
#  ('w', 4051),
#  ('k', 3872),
#  ('x', 1369),
#  ('q', 850),
#  ('j', 795),
#  ('z', 704),
#  ('-', 1)]

# %%
def unig(mask,guessed):
    for item in sorted_x:
        if item[0] not in guessed:
            return item[0]
hangman('whatever', unig, 8, True)
# Out:
# Starting hangman game. Target is _ _ _ _ _ _ _ _ length 8
# You have 8 attempts remaining.
# Guess is e
# Good guess: _ _ _ _ e _ e _
# You have 8 attempts remaining.
# Guess is i
# Sorry, try again.
# You have 7 attempts remaining.
# Guess is s
# Sorry, try again.
# You have 6 attempts remaining.
# Guess is a
# Good guess: _ _ a _ e _ e _
# You have 6 attempts remaining.
# Guess is r
# Good guess: _ _ a _ e _ e r
# You have 6 attempts remaining.
# Guess is n
# Sorry, try again.
# You have 5 attempts remaining.
# Guess is t
# Good guess: _ _ a t e _ e r
# You have 5 attempts remaining.
# Guess is o
# Sorry, try again.
# You have 4 attempts remaining.
# Guess is l
# Sorry, try again.
# You have 3 attempts remaining.
# Guess is c
# Sorry, try again.
# You have 2 attempts remaining.
# Guess is d
# Sorry, try again.
# You have 1 attempts remaining.
# Guess is u
# Sorry, try again.
# Out of guesses. The word was whatever
# 8

# %%
totMist = 0
corrs = 0
for i,item in enumerate(test):
    mist = hangman(item, unig, 8, False)
    totMist += mist
    if mist < 8:
        corrs += 1

corrs,totMist
# Out:
# (301, 7229)

# %% [markdown]
# ## unigram with Length

# %%
from collections import defaultdict
frequni = defaultdict(dict)
for item in train:
    for chara in item:
        try:
            frequni[len(item)][chara] += 1
        except:
            frequni[len(item)][chara] = 1

# %%
def unigLen(mask,guessed):
    sorted_x = sorted(frequni[len(mask)].items(), key=operator.itemgetter(1),reverse=True)
    for item in sorted_x:
        if item[0] not in guessed:
            return item[0]
        
totMist = 0
corrs = 0
for i,item in enumerate(test):
    mist = hangman(item, unigLen, 8, False)
    totMist += mist
    if mist < 8:
        corrs += 1
print (corrs,totMist)
# Out:
# 305 7213

# %% [markdown]
# ## Unigram with Position

# %%
from collections import defaultdict
frequni = defaultdict(dict)
posCountDict = dict()
for item in train:
    for pos,chara in enumerate(item):
        try:
            frequni[pos][chara] += 1
        except KeyError:
            frequni[pos][chara] = 1
        try:
            posCountDict[pos] += 1
        except KeyError:
            posCountDict[pos] = 1

# %%
posCountDict
# Out:
# {0: 57107,
#  1: 57107,
#  2: 57061,
#  3: 56480,
#  4: 54228,
#  5: 50036,
#  6: 43220,
#  7: 34165,
#  8: 24919,
#  9: 17364,
#  10: 11119,
#  11: 6646,
#  12: 3591,
#  13: 1740,
#  14: 828,
#  15: 345,
#  16: 153,
#  17: 57,
#  18: 21,
#  19: 12,
#  20: 3,
#  21: 1}

# %%
freqProb = defaultdict(dict)
for item in frequni.keys():
    for stuff in frequni[item].keys():
        freqProb[item][stuff] = frequni[item][stuff]*1.0/posCountDict[item]

# %%
def unigPos(mask,guessed):
    locDict = dict()
    for item in freqProb.keys():
        sorted_x = sorted(freqProb[item].items(), key=operator.itemgetter(1),reverse=True)
        locDict[sorted_x[0][0]] = sorted_x[0][1]
    sorted_x = sorted(locDict.items(), key=operator.itemgetter(1),reverse=True)
    print(sorted_x)
    for item in sorted_x:
        if item[0] not in guessed:
            return item[0]
        
totMist = 0
corrs = 0
for i,item in enumerate(test):
    mist = hangman(item, unigLen, 8, False)
    totMist += mist
    if mist < 8:
        corrs += 1
print (corrs,totMist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-92ff9c1e77f4> in <module>()
#      10 corrs = 0
#      11 for i,item in enumerate(test):
# ---> 12     mist = hangman(item, unigLen, 8, False)
#      13     totMist += mist
#      14     if mist < 8:
#
# <ipython-input-3-9ca3c4a377cf> in hangman(secret_word, guesser, max_mistakes, verbose)
#      23         else:
#      24             guessed.add(guess)
# ---> 25             if guess in secret_word:
#      26                 for i, c in enumerate(secret_word):
#      27                     if c == guess:
#
# TypeError: 'in <string>' requires string as left operand, not NoneType

# %%
    locDict = dict()
    for item in freqProb.keys():
        sorted_x = sorted(freqProb[item].items(), key=operator.itemgetter(1),reverse=True)
        locDict[sorted_x[0][0]] = sorted_x[0][1]
    sorted_x = sorted(locDict.items(), key=operator.itemgetter(1),reverse=True)
    print(sorted_x)
    for item in sorted_x:
        if item[0] not in guessed:
            return item[0]
# Out:
# [('s', 0.11478452729087503), ('c', 0.09452431400703942), ('p', 0.07851927084245364), ('d', 0.06498327700632146), ('r', 0.06253173866601293), ('a', 0.059870068467963646), ('b', 0.055229656609522476), ('m', 0.05065928870366155), ('t', 0.049591118426812825), ('i', 0.046001365857075316), ('e', 0.04454795384103525), ('f', 0.04400511320853836), ('h', 0.034864377396816505), ('u', 0.033043234629730155), ('l', 0.03160733360183515), ('g', 0.03158982261369009), ('w', 0.026546658027912517), ('o', 0.0239024988180083), ('n', 0.015812422294990105), ('v', 0.013956257551613638), ('j', 0.008142609487453377), ('k', 0.006093823874481237), ('q', 0.004990631621342392), ('y', 0.0024690493284536047), ('z', 0.0014884339923301871), ('x', 0.0002451538340308544)]
# [('e', 0.15714360761377766), ('o', 0.1346945208118094), ('a', 0.12963384523788676), ('i', 0.0967832314777523), ('r', 0.08687201218764774), ('n', 0.08086574325389181), ('u', 0.07464934246239516), ('l', 0.04692944822876355), ('h', 0.03637032237729175), ('t', 0.02339468016180153), ('p', 0.020260213283835607), ('m', 0.018176405694573346), ('c', 0.016810548619258583), ('x', 0.011749873045335948), ('y', 0.011469697235014972), ('s', 0.010103840159700212), ('v', 0.009105713835431734), ('d', 0.008300208380758926), ('b', 0.007617279843101546), ('w', 0.006601642530688007), ('f', 0.003362109723851717), ('g', 0.003222021818691229), ('q', 0.0029068240320801303), ('k', 0.0025390932810338486), ('z', 0.00022764284588579334), ('j', 0.00021013185774073232)]
# [('r', 0.09433763866739103), ('a', 0.09184907379821594), ('n', 0.07919594819579047), ('s', 0.07064369709609016), ('e', 0.0692767389285151), ('t', 0.06771700460910254), ('o', 0.06573666777658997), ('i', 0.060076058954452255), ('l', 0.0587792012057272), ('c', 0.05197946057727695), ('p', 0.04255095424195159), ('u', 0.040921119503689034), ('m', 0.04015001489633901), ('d', 0.033753351676276265), ('g', 0.02609488091691348), ('b', 0.02343106500061338), ('f', 0.020223970838225757), ('v', 0.018243634005713185), ('w', 0.009761483324862865), ('y', 0.008867702984525333), ('h', 0.00827184942430031), ('x', 0.004609102539387673), ('k', 0.004363751073412664), ('z', 0.003312244790662624), ('j', 0.003119468638825117), ('q', 0.0027339163351501024)]
# [('e', 0.11972379603399433), ('t', 0.08597733711048158), ('i', 0.083764164305949), ('r', 0.07314093484419264), ('a', 0.06620042492917846), ('o', 0.05954320113314448), ('s', 0.05715297450424929), ('l', 0.05660410764872521), ('n', 0.05428470254957507), ('c', 0.045874645892351275), ('d', 0.03967776203966006), ('p', 0.0391643059490085), ('u', 0.037128186968838524), ('m', 0.033179886685552405), ('g', 0.02816926345609065), ('k', 0.022698300283286118), ('h', 0.02161827195467422), ('b', 0.018572946175637393), ('f', 0.0181657223796034), ('v', 0.013526912181303117), ('w', 0.008923512747875353), ('y', 0.007524787535410765), ('z', 0.0034525495750708213), ('x', 0.002106940509915014), ('q', 0.002071529745042493), ('j', 0.0017528328611898017)]
# [('e', 0.13780703695507857), ('i', 0.10642103710260382), ('r', 0.08097292911411079), ('t', 0.07361510658700303), ('s', 0.06974256841484104), ('a', 0.06883897617466991), ('l', 0.06585158958471639), ('o', 0.062181898650143834), ('n', 0.05910230877037693), ('u', 0.034207420520764184), ('c', 0.032861252489488825), ('d', 0.029966069189348677), ('h', 0.028933392343438814), ('p', 0.02565095522608247), ('m', 0.025226820092940916), ('g', 0.021206756657077525), ('k', 0.015858965847901453), ('b', 0.015600796636423988), ('y', 0.013701408866268349), ('f', 0.012834697942022572), ('v', 0.0075975510806225565), ('w', 0.006878365420078188), ('z', 0.002194438297558457), ('x', 0.0014752526370140886), ('q', 0.0009035922401711293), ('j', 0.00036881315925352216)]
# [('e', 0.13752098489087858), ('i', 0.10892157646494524), ('r', 0.08369973618994324), ('n', 0.08262051323047406), ('t', 0.07890318970341355), ('s', 0.07864337676872651), ('a', 0.07174834119434008), ('l', 0.05546006875049964), ('o', 0.04566711967383484), ('d', 0.039771364617475415), ('c', 0.03693340794627868), ('u', 0.024602286353825244), ('g', 0.02426253097769606), ('m', 0.023603005835798226), ('h', 0.021244703813254457), ('p', 0.01744743784475178), ('y', 0.016628027819969624), ('b', 0.013090574786153969), ('f', 0.012471020864977216), ('v', 0.009613078583419938), ('w', 0.008353985130705892), ('k', 0.004556719162203213), ('x', 0.0019186185946118795), ('z', 0.0010392517387481015), ('q', 0.00097929490766648), ('j', 0.0002797985450475658), ('-', 1.9985610360540412e-05)]
# [('e', 0.1341277186487737), ('i', 0.10853771402128644), ('s', 0.10788986580286904), ('t', 0.08660342434058306), ('a', 0.08044886626561777), ('n', 0.07919944470152707), ('r', 0.07309116149930588), ('l', 0.051920407218880145), ('o', 0.051573345673299395), ('d', 0.044099953725127254), ('g', 0.03683479870430356), ('c', 0.027602961591855622), ('u', 0.023577047663118928), ('y', 0.01941230911614993), ('m', 0.016959740860712634), ('h', 0.015340120314669135), ('p', 0.011753817677001389), ('b', 0.008098102730217492), ('v', 0.005992596020360944), ('f', 0.005622397038408144), ('k', 0.0054835724201758446), ('w', 0.0031004164738546967), ('x', 0.0015964831096714485), ('z', 0.0007403979639055993), ('q', 0.00027764923646459973), ('j', 0.00011568718186024989)]
# [('e', 0.12509878530660032), ('s', 0.12199619493633836), ('i', 0.10329284355334406), ('t', 0.09433630908824821), ('n', 0.09208254061173715), ('a', 0.06184691936192009), ('r', 0.061583491877652566), ('l', 0.0529196546172984), ('d', 0.05133908971169325), ('g', 0.04466559344358261), ('o', 0.04220693692375238), ('c', 0.03000146348602371), ('y', 0.02288892141080053), ('u', 0.01934728523342602), ('m', 0.015688570174154835), ('h', 0.014020196107127177), ('p', 0.011473730425874433), ('b', 0.011210302941606907), ('v', 0.007610127323284062), ('k', 0.00722962095711986), ('f', 0.005034391921557149), ('w', 0.002897702326942778), ('x', 0.0007902824528025757), ('q', 0.0002048880433191863), ('z', 0.00017561832284501683), ('j', 5.853944094833894e-05)]
# [('e', 0.1363618122717605), ('s', 0.12540631646534772), ('i', 0.09988362293832016), ('n', 0.09514828042858862), ('t', 0.09105501825915968), ('a', 0.059713471648139976), ('d', 0.05357357839399655), ('l', 0.05212889762831574), ('g', 0.04915927605441631), ('r', 0.048156025522693525), ('o', 0.04482523375737389), ('c', 0.02829166499458245), ('y', 0.027890364781893336), ('u', 0.01833941971989245), ('m', 0.014968497933303905), ('h', 0.01260082667843814), ('b', 0.011838356274328825), ('v', 0.00914964484931177), ('p', 0.008387174445202455), ('k', 0.006501063445563626), ('f', 0.0036117019142020146), ('w', 0.001484810786949717), ('x', 0.0007624704041093142), ('z', 0.00040130021268911274), ('q', 0.0003611701914202014)]
# [('s', 0.14449435613913844), ('e', 0.13119096982262152), ('n', 0.09991937341626353), ('i', 0.09237502879520848), ('t', 0.08903478461184058), ('l', 0.06190969822621516), ('g', 0.0543653536051601), ('d', 0.053386316516931584), ('a', 0.048491131075788986), ('o', 0.044978115641557244), ('r', 0.042271366044690166), ('y', 0.038931121861322276), ('c', 0.02631882054826077), ('u', 0.015146279659064732), ('h', 0.013130615065653075), ('m', 0.012093987560469938), ('b', 0.010999769638332182), ('v', 0.008062658373646624), ('p', 0.005931812946325731), ('k', 0.004088919603777931), ('f', 0.00138217000691085), ('w', 0.0009790370882285188), ('x', 0.00046072333563695), ('z', 5.759041695461875e-05)]
# [('s', 0.150732979584495), ('e', 0.1283388793956291), ('n', 0.10909254429355157), ('i', 0.09398327187696735), ('l', 0.07815451029768865), ('t', 0.07482687292022663), ('g', 0.056479899271517225), ('y', 0.05360194262073927), ('d', 0.05207302815001349), ('o', 0.04577749797643673), ('a', 0.041910243726953865), ('r', 0.04002158467488084), ('c', 0.024372695386275744), ('b', 0.01025272056839644), ('m', 0.0082741253709866), ('u', 0.008094253080312978), ('h', 0.007734508498965734), ('v', 0.005845849446892706), ('p', 0.005306232574871841), ('k', 0.002428275924093893), ('f', 0.0017087867613994063), ('w', 0.0007194891626944869), ('z', 0.00017987229067362173), ('x', 8.993614533681087e-05)]
# [('s', 0.1691242852843816), ('n', 0.11149563647306651), ('e', 0.10427324706590431), ('l', 0.08727053866987662), ('i', 0.08110141438459223), ('y', 0.08004814926271442), ('t', 0.06936503159795365), ('g', 0.05823051459524526), ('d', 0.051309058080048146), ('o', 0.05040625940415287), ('a', 0.04122780619921757), ('r', 0.026181161600962986), ('c', 0.0255792958170328), ('u', 0.008275654529040024), ('m', 0.007974721637074932), ('v', 0.0072223894071622025), ('b', 0.006770990069214565), ('p', 0.006169124285284382), ('h', 0.004363526933493831), ('w', 0.0012037315678603672), ('f', 0.0012037315678603672), ('k', 0.0010532651218778213), ('x', 0.0001504664459825459)]
# [('s', 0.18574213311055415), ('n', 0.1189083820662768), ('y', 0.10526315789473684), ('e', 0.09523809523809523), ('l', 0.09440267335004177), ('i', 0.07128933444722918), ('t', 0.06627680311890838), ('g', 0.05513784461152882), ('o', 0.04622667780562517), ('d', 0.037037037037037035), ('c', 0.03508771929824561), ('a', 0.031467557783347255), ('r', 0.022834864940128097), ('m', 0.01113895850737956), ('h', 0.005012531328320802), ('b', 0.004455583402951824), ('v', 0.004455583402951824), ('p', 0.004177109440267335), ('u', 0.00278473962684489), ('k', 0.002227791701475912), ('w', 0.000556947925368978), ('x', 0.000278473962684489)]
# [('s', 0.21551724137931033), ('n', 0.11839080459770115), ('y', 0.10977011494252874), ('l', 0.10517241379310345), ('e', 0.08505747126436781), ('t', 0.07586206896551724), ('i', 0.06954022988505747), ('o', 0.04310344827586207), ('g', 0.04310344827586207), ('a', 0.03908045977011494), ('d', 0.029310344827586206), ('c', 0.01954022988505747), ('r', 0.01839080459770115), ('m', 0.008620689655172414), ('h', 0.004597701149425287), ('u', 0.004022988505747126), ('v', 0.004022988505747126), ('b', 0.0034482758620689655), ('p', 0.0028735632183908046), ('w', 0.0005747126436781609)]
# [('s', 0.22342995169082125), ('y', 0.15579710144927536), ('n', 0.11714975845410629), ('l', 0.10144927536231885), ('t', 0.07125603864734299), ('e', 0.06280193236714976), ('i', 0.059178743961352656), ('g', 0.043478260869565216), ('o', 0.03864734299516908), ('d', 0.035024154589371984), ('a', 0.03140096618357488), ('c', 0.027777777777777776), ('r', 0.010869565217391304), ('m', 0.010869565217391304), ('v', 0.0036231884057971015), ('p', 0.0024154589371980675), ('h', 0.0024154589371980675), ('b', 0.0024154589371980675)]
# [('s', 0.19710144927536233), ('l', 0.15072463768115943), ('y', 0.13333333333333333), ('n', 0.09855072463768116), ('e', 0.08115942028985507), ('o', 0.06666666666666667), ('t', 0.05217391304347826), ('i', 0.043478260869565216), ('a', 0.03768115942028986), ('g', 0.03188405797101449), ('r', 0.03188405797101449), ('c', 0.028985507246376812), ('m', 0.02318840579710145), ('d', 0.005797101449275362), ('v', 0.005797101449275362), ('b', 0.005797101449275362), ('k', 0.002898550724637681), ('p', 0.002898550724637681)]
# [('y', 0.21568627450980393), ('s', 0.19607843137254902), ('n', 0.1830065359477124), ('l', 0.0784313725490196), ('o', 0.05228758169934641), ('t', 0.05228758169934641), ('e', 0.0457516339869281), ('a', 0.032679738562091505), ('m', 0.026143790849673203), ('d', 0.026143790849673203), ('r', 0.026143790849673203), ('g', 0.0196078431372549), ('p', 0.0196078431372549), ('c', 0.013071895424836602), ('i', 0.013071895424836602)]
# [('s', 0.24561403508771928), ('n', 0.17543859649122806), ('y', 0.12280701754385964), ('i', 0.08771929824561403), ('l', 0.08771929824561403), ('a', 0.07017543859649122), ('t', 0.05263157894736842), ('g', 0.05263157894736842), ('e', 0.03508771929824561), ('r', 0.017543859649122806), ('h', 0.017543859649122806), ('o', 0.017543859649122806), ('c', 0.017543859649122806)]
# [('o', 0.14285714285714285), ('l', 0.14285714285714285), ('s', 0.14285714285714285), ('y', 0.09523809523809523), ('r', 0.09523809523809523), ('c', 0.09523809523809523), ('n', 0.09523809523809523), ('a', 0.047619047619047616), ('i', 0.047619047619047616), ('m', 0.047619047619047616), ('e', 0.047619047619047616)]
# [('n', 0.25), ('i', 0.16666666666666666), ('y', 0.16666666666666666), ('m', 0.08333333333333333), ('c', 0.08333333333333333), ('a', 0.08333333333333333), ('e', 0.08333333333333333), ('s', 0.08333333333333333)]
# [('e', 0.3333333333333333), ('l', 0.3333333333333333), ('a', 0.3333333333333333)]
# [('s', 1.0)]

# %% [markdown]
# ### bi-gram Models

# %%
from collections import defaultdict
bigram = defaultdict(dict)

for item in train:
    item2 = '$'+item+'$'
    print(item2)
    for i,chara in enumerate(item2):
        try:
            print(chara,item2[i+1])
            bigram[chara][item2[i+1]] += 1
        except:
            try:
                
                bigram[chara][item2[i+1]] = 1
            except IndexError:
                print(chara,item2[min(i+1,len(item2)-1)],'except')
                pass
    
    break
# Out:
# $prayerbook$
# $ p
# p r
# r a
# a y
# y e
# e r
# r b
# b o
# o o
# o k
# k $
# $ $ except

# %% [markdown]
# ### N-gram Models

# %%
from collections import defaultdict

def ngramModel(train,ngt,countsOnly=1):
    ng = ngt - 1
    bigram = defaultdict(dict)
    outerKeys =dict()
    for item in train:
        item2 = '$'+item+'$'
        for i,chara in enumerate(item2):
            if i+ng >= len(item2)-1:
                break
            try:
                bigram[item2[i:i+ng]][item2[i+ng]] += 1
            except:
                try:
                    bigram[item2[i:i+ng]][item2[i+ng]] = 1
                except IndexError:
                    pass
    for item in bigram.keys():
        for stuff in bigram[item]:
            try:
                outerKeys[item] += bigram[item][stuff]
            except:
                outerKeys[item] = bigram[item][stuff]
    if countsOnly != 1:
        for item in bigram.keys():
            try:
                del bigram[item]['$']
            except:
                pass
            for stuff in bigram[item]:
                bigram[item][stuff] = (1.0*bigram[item][stuff])/outerKeys[item]
    
    return bigram,outerKeys

# %%
ngModels = dict()
outKeys = dict()

for i in range(2,6):
    ngModels[i],outKeys[i] = ngramModel(train,i)

# %%
ngModels[5]
# Out:
# defaultdict(dict,
#             {'$pra': {'c': 16,
#               'g': 7,
#               'i': 6,
#               'l': 1,
#               'm': 2,
#               'n': 9,
#               't': 5,
#               'w': 2,
#               'y': 9},
#              'pray': {'e': 10, 'i': 2, 's': 4},
#              'raye': {'d': 13, 'r': 10},
#              'ayer': {'b': 1, 'e': 1, 'f': 2, 'i': 1, 's': 14},
#              'yerb': {'o': 1},
#              'erbo': {'a': 7, 'd': 1, 'l': 8, 'o': 1, 's': 4, 'u': 1, 'x': 4},
#              'rboo': {'k': 3},
#              '$hol': {'d': 12,
#               'e': 4,
#               'i': 14,
#               'l': 10,
#               'm': 1,
#               'o': 6,
#               's': 2,
#               'y': 1},
#              'holo': {'c': 2, 'g': 47},
#              'olog': {'e': 5,
#               'i': 217,
#               'n': 2,
#               'o': 3,
#               'r': 4,
#               'u': 9,
#               'y': 94},
#              'logr': {'a': 11},
#              'ogra': {'d': 1, 'm': 38, 'p': 145, 'v': 1},
#              'grap': {'e': 4, 'h': 176, 'n': 1, 'p': 4, 't': 1},
#              'raph': {'e': 40, 'i': 73, 'o': 5, 'r': 4, 's': 14, 'y': 35},
#              'aphi': {'c': 63, 'd': 2, 'e': 3, 'm': 1, 'n': 5, 't': 1},
#              '$wea': {'k': 15,
#               'l': 5,
#               'n': 5,
#               'p': 3,
#               'r': 16,
#               's': 3,
#               't': 13,
#               'v': 7},
#              'wear': {'a': 1, 'e': 4, 'i': 11, 's': 2, 'w': 2, 'y': 4},
#              'eari': {'e': 8, 'l': 3, 'n': 33, 's': 3, 't': 1},
#              'aril': {'y': 23},
#              '$hum': {'a': 20,
#               'b': 10,
#               'd': 1,
#               'e': 1,
#               'i': 13,
#               'm': 9,
#               'o': 7,
#               'p': 5,
#               's': 1,
#               'u': 1},
#              'hume': {'d': 1, 'r': 1, 's': 1},
#              'umer': {'a': 20, 'i': 5, 'o': 5, 's': 1, 'u': 1, 'y': 1},
#              'meru': {'s': 1},
#              '$pro': {'a': 1,
#               'b': 23,
#               'c': 50,
#               'd': 26,
#               'f': 62,
#               'g': 28,
#               'h': 10,
#               'j': 13,
#               'k': 1,
#               'l': 22,
#               'm': 45,
#               'n': 17,
#               'o': 9,
#               'p': 90,
#               's': 56,
#               't': 68,
#               'u': 4,
#               'v': 44,
#               'w': 9,
#               'x': 8},
#              'pron': {'e': 3, 'g': 1, 'o': 15, 's': 1, 't': 1, 'u': 4},
#              'rono': {'l': 6, 'm': 18, 'u': 19},
#              'onom': {'a': 1, 'e': 14, 'i': 37, 'o': 3, 'y': 6},
#              'nomi': {'a': 6, 'c': 25, 'e': 3, 'n': 22, 's': 10},
#              'omin': {'a': 40, 'e': 11, 'g': 28, 'i': 5, 'o': 3, 'y': 1},
#              'mina': {'b': 7, 'c': 3, 'l': 23, 'n': 16, 'r': 12, 't': 127},
#              '$fas': {'c': 12, 'h': 6, 't': 18},
#              'fast': {'e': 13, 'i': 5, 'l': 1, 'n': 3, 's': 2},
#              'aste': {'b': 1,
#               'c': 1,
#               'd': 22,
#               'f': 7,
#               'l': 9,
#               'n': 15,
#               'p': 1,
#               'r': 89,
#               's': 7,
#               'u': 4},
#              'sten': {'a': 1,
#               'c': 15,
#               'd': 1,
#               'e': 13,
#               'i': 9,
#               'o': 5,
#               's': 8,
#               't': 23},
#              'teni': {'n': 33, 's': 1},
#              'enin': {'e': 1, 'g': 99, 's': 3},
#              'ning': {'f': 3, 'i': 1, 'l': 22, 's': 34},
#              '$sci': {'a': 1, 'e': 6, 'f': 1, 'm': 2, 'n': 8, 's': 3},
#              'scin': {'a': 7, 'd': 3, 'g': 5, 't': 8},
#              'cint': {'h': 2, 'i': 8, 'o': 2},
#              'inti': {'c': 1,
#               'e': 6,
#               'f': 3,
#               'g': 2,
#               'l': 11,
#               'm': 15,
#               'n': 32,
#               'v': 2},
#              'ntil': {'a': 10,
#               'e': 11,
#               'i': 1,
#               'l': 10,
#               'o': 1,
#               's': 1,
#               'y': 2},
#              'till': {'a': 18, 'b': 2, 'e': 13, 'i': 8, 'n': 1, 's': 3},
#              'illa': {'b': 3,
#               'd': 2,
#               'g': 12,
#               'i': 4,
#               'n': 1,
#               'r': 8,
#               's': 4,
#               't': 32},
#              'llat': {'e': 21, 'i': 32, 'o': 7},
#              'lato': {'n': 2, 'o': 2, 'r': 56},
#              'ator': {'i': 23, 's': 116, 'y': 69},
#              '$dio': {'c': 2, 'd': 2, 'p': 2, 'x': 4},
#              'diox': {'i': 4},
#              'ioxi': {'d': 3, 'n': 2},
#              'oxin': {'e': 1, 'g': 3, 's': 2},
#              '$clo': {'a': 8,
#               'b': 1,
#               'c': 7,
#               'd': 1,
#               'g': 4,
#               'i': 3,
#               'n': 5,
#               's': 20,
#               't': 14,
#               'u': 15,
#               'v': 4,
#               'w': 5,
#               'y': 2},
#              'clow': {'n': 5},
#              'lown': {'e': 5, 'i': 2, 's': 1},
#              'owni': {'e': 2, 'n': 11, 's': 2},
#              'wnin': {'g': 20},
#              '$shu': {'d': 4, 'f': 5, 'n': 10, 's': 1, 't': 16},
#              'shun': {'d': 1, 'n': 2, 's': 1, 't': 6},
#              'hunt': {'e': 11, 'i': 4, 's': 7},
#              'unti': {'d': 5,
#               'e': 11,
#               'f': 2,
#               'l': 1,
#               'm': 1,
#               'n': 28,
#               'r': 1,
#               't': 1},
#              'ntin': {'e': 22, 'g': 132, 'l': 1, 'u': 26},
#              '$qui': {'b': 3,
#               'c': 15,
#               'd': 2,
#               'e': 17,
#               'f': 1,
#               'l': 6,
#               'n': 13,
#               'p': 4,
#               'r': 6,
#               's': 1,
#               't': 6,
#               'v': 5,
#               'x': 1,
#               'z': 6},
#              'quir': {'e': 26, 'i': 8, 'k': 5, 'm': 4, 'r': 3, 't': 4, 'y': 2},
#              '$acq': {'u': 30},
#              'acqu': {'a': 8, 'e': 5, 'i': 26},
#              'cqui': {'e': 5, 'r': 7, 's': 5, 't': 9},
#              'quis': {'h': 8, 'i': 27, 'l': 1, 't': 4},
#              'uisi': {'n': 4, 't': 27},
#              'isit': {'a': 5, 'e': 10, 'i': 18, 'o': 5, 's': 2},
#              'siti': {'c': 2, 'e': 14, 'n': 7, 'o': 68, 's': 7, 'v': 31},
#              'itiv': {'e': 59, 'i': 10},
#              'tive': {'l': 109, 'n': 45, 's': 52},
#              'iven': {'e': 86, 'i': 2, 's': 2},
#              'vene': {'d': 9, 'e': 3, 'r': 9, 's': 86, 't': 1},
#              'enes': {'i': 5, 's': 215, 't': 6},
#              '$pan': {'a': 4,
#               'c': 5,
#               'd': 9,
#               'e': 8,
#               'g': 5,
#               'i': 6,
#               'j': 1,
#               'n': 4,
#               'o': 4,
#               's': 3,
#               't': 22,
#               'z': 1},
#              '$pie': {'b': 1, 'c': 7, 'd': 1, 'r': 8, 's': 1, 't': 2, 'z': 1},
#              'pier': {'c': 6, 's': 5},
#              'ierc': {'e': 9, 'i': 2},
#              'erce': {'d': 4, 'i': 6, 'l': 1, 'n': 9, 'p': 21, 'r': 4, 's': 5},
#              '$ato': {'l': 2, 'm': 9, 'n': 8},
#              'atom': {'a': 1, 'b': 1, 'i': 16, 's': 2, 'y': 1},
#              'tomi': {'c': 10, 'e': 5, 'm': 2, 'n': 2, 's': 18},
#              'omic': {'a': 12, 'i': 7, 's': 4},
#              'mici': {'a': 2, 'd': 5, 'l': 3, 'r': 2, 's': 1, 't': 1},
#              'icit': {'a': 5,
#               'e': 3,
#               'i': 11,
#               'l': 3,
#               'n': 1,
#               'o': 8,
#               's': 3,
#               'u': 1,
#               'y': 26},
#              '$unp': {'a': 16,
#               'e': 6,
#               'h': 1,
#               'i': 3,
#               'l': 12,
#               'o': 7,
#               'r': 34,
#               'u': 6},
#              'unpl': {'a': 4, 'e': 4, 'o': 1, 'u': 3},
#              'nplu': {'g': 3, 's': 1},
#              'plug': {'g': 6, 'h': 1, 's': 2},
#              'lugg': {'a': 3, 'e': 5, 'i': 8},
#              'uggi': {'e': 2, 'n': 14, 's': 5},
#              'ggin': {'g': 50},
#              '$oct': {'a': 12, 'e': 2, 'o': 5},
#              'octa': {'g': 3, 'h': 2, 'l': 1, 'n': 3, 'v': 3},
#              'ctah': {'e': 2},
#              'tahe': {'d': 2},
#              'ahed': {'r': 12},
#              'hedr': {'a': 12, 'o': 6},
#              'edro': {'c': 1, 'n': 6, 'o': 2, 'p': 1},
#              '$pre': {'a': 15,
#               'b': 2,
#               'c': 60,
#               'd': 55,
#               'e': 4,
#               'f': 27,
#               'g': 3,
#               'h': 5,
#               'j': 8,
#               'l': 7,
#               'm': 25,
#               'n': 1,
#               'o': 6,
#               'p': 25,
#               'r': 2,
#               's': 94,
#               't': 29,
#               'v': 28,
#               'y': 4},
#              'prec': {'a': 16,
#               'e': 15,
#               'h': 2,
#               'i': 41,
#               'l': 5,
#               'o': 13,
#               'u': 2},
#              'reci': {'a': 17,
#               'd': 3,
#               'n': 2,
#               'o': 3,
#               'p': 21,
#               'r': 4,
#               's': 10,
#               't': 10},
#              'ecip': {'e': 2, 'h': 7, 'i': 12, 'r': 7},
#              'cipi': {'c': 2, 'e': 4, 't': 9},
#              'ipit': {'a': 7, 'o': 4, 's': 1, 'y': 1},
#              'pita': {'b': 3, 'l': 18, 'p': 3, 't': 19, 'x': 2},
#              'itat': {'e': 57, 'i': 89, 'o': 9, 's': 1},
#              'tati': {'c': 16, 'n': 36, 'o': 214, 's': 6, 'v': 29},
#              'atin': {'a': 3,
#               'e': 4,
#               'g': 446,
#               'o': 2,
#               's': 2,
#               'u': 1,
#               'w': 1,
#               'y': 1},
#              '$bra': {'b': 3,
#               'c': 15,
#               'd': 2,
#               'g': 6,
#               'h': 2,
#               'i': 30,
#               'k': 4,
#               'm': 2,
#               'n': 17,
#               's': 12,
#               't': 3,
#               'v': 10,
#               'w': 10,
#               'y': 4,
#               'z': 9},
#              'brai': {'c': 3, 'd': 7, 'l': 2, 'n': 26, 's': 3},
#              'rain': {'a': 1,
#               'b': 2,
#               'c': 7,
#               'd': 6,
#               'e': 28,
#               'f': 3,
#               'i': 15,
#               'l': 5,
#               'm': 1,
#               'o': 1,
#               'p': 3,
#               's': 18,
#               't': 8,
#               'w': 6,
#               'y': 3},
#              'ains': {'a': 5, 'c': 2, 'i': 2, 'm': 3, 'p': 1, 't': 11, 'w': 1},
#              'inst': {'a': 40, 'e': 9, 'i': 30, 'o': 5, 'r': 26},
#              'nsto': {'n': 3, 'p': 3, 'r': 6},
#              'stor': {'a': 7,
#               'e': 20,
#               'i': 15,
#               'k': 1,
#               'm': 22,
#               's': 9,
#               't': 8,
#               'y': 9},
#              'torm': {'e': 8, 'i': 5, 's': 6, 't': 1, 'y': 1},
#              '$esc': {'a': 23, 'h': 6, 'o': 4, 'u': 1},
#              'esca': {'l': 15, 'n': 5, 'p': 13, 'r': 4},
#              'scar': {'a': 3,
#               'c': 7,
#               'd': 4,
#               'e': 7,
#               'f': 3,
#               'i': 7,
#               'l': 2,
#               'p': 5,
#               'r': 7,
#               's': 2,
#               'v': 2,
#               'y': 1},
#              '$the': {'a': 6,
#               'b': 1,
#               'e': 1,
#               'f': 2,
#               'i': 6,
#               'm': 8,
#               'n': 4,
#               'o': 27,
#               'r': 37,
#               's': 6,
#               't': 1,
#               'y': 1},
#              'theo': {'c': 2, 'd': 2, 'l': 7, 'n': 1, 'r': 15, 's': 2},
#              'heol': {'o': 9},
#              'eolo': {'g': 31},
#              'logi': {'a': 3, 'c': 108, 'e': 22, 's': 116},
#              'ogic': {'a': 104, 'i': 2, 's': 1},
#              'gica': {'l': 116},
#              'ical': {'i': 17, 'l': 326, 's': 15},
#              'call': {'a': 1,
#               'e': 6,
#               'g': 2,
#               'i': 10,
#               'o': 8,
#               's': 3,
#               'u': 2,
#               'y': 333},
#              'escu': {'d': 1, 'e': 5, 'i': 1},
#              'scud': {'d': 2, 'o': 1, 's': 1},
#              '$gas': {'e': 2,
#               'h': 5,
#               'i': 1,
#               'k': 2,
#               'l': 1,
#               'o': 1,
#               'p': 5,
#               's': 5,
#               't': 9,
#               'w': 1},
#              'gast': {'a': 1, 'e': 1, 'r': 9},
#              'astr': {'a': 10, 'e': 2, 'i': 5, 'o': 34, 'u': 3, 'y': 1},
#              'stro': {'d': 2,
#               'e': 1,
#               'g': 2,
#               'i': 2,
#               'k': 9,
#               'l': 12,
#               'm': 2,
#               'n': 28,
#               'o': 1,
#               'p': 20,
#               's': 1,
#               'u': 5,
#               'v': 1,
#               'y': 7},
#              'troi': {'d': 2, 'k': 2, 'n': 1, 't': 1},
#              'roin': {'e': 2, 'g': 1, 's': 1, 't': 1},
#              'oint': {'b': 1,
#               'e': 18,
#               'i': 10,
#               'l': 3,
#               'm': 7,
#               'n': 1,
#               's': 11,
#               'u': 1,
#               'y': 1},
#              'inte': {'a': 2,
#               'd': 37,
#               'e': 2,
#               'g': 26,
#               'l': 20,
#               'm': 2,
#               'n': 35,
#               'r': 313,
#               's': 10,
#               't': 2},
#              'ntes': {'s': 6, 't': 21},
#              'test': {'a': 22,
#               'd': 2,
#               'e': 15,
#               'i': 27,
#               'o': 3,
#               's': 6,
#               't': 1},
#              'esti': {'a': 5,
#               'b': 9,
#               'c': 22,
#               'd': 3,
#               'e': 5,
#               'f': 4,
#               'g': 16,
#               'l': 4,
#               'm': 25,
#               'n': 46,
#               'o': 25,
#               'r': 3,
#               's': 2,
#               't': 6,
#               'v': 12,
#               'z': 1},
#              'stin': {'a': 13,
#               'c': 16,
#               'e': 19,
#               'g': 135,
#               'i': 1,
#               'k': 6,
#               't': 5,
#               'y': 1},
#              'tina': {'c': 4, 'l': 3, 's': 1, 't': 15},
#              '$sho': {'a': 2,
#               'c': 7,
#               'd': 6,
#               'e': 13,
#               'g': 2,
#               'n': 1,
#               'o': 10,
#               'p': 15,
#               'r': 48,
#               't': 4,
#               'u': 10,
#               'v': 10,
#               'w': 30},
#              'shor': {'e': 15, 'i': 1, 'n': 2, 't': 41},
#              'hort': {'a': 3,
#               'b': 1,
#               'c': 8,
#               'e': 10,
#               'f': 2,
#               'h': 1,
#               'i': 7,
#               'l': 9,
#               'n': 1,
#               's': 7,
#               't': 2,
#               'w': 1,
#               'y': 1},
#              'orta': {'b': 20,
#               'g': 4,
#               'l': 12,
#               'n': 4,
#               'r': 2,
#               's': 1,
#               't': 6},
#              'rtag': {'e': 4},
#              'tage': {'c': 2,
#               'd': 5,
#               'h': 1,
#               'm': 2,
#               'n': 1,
#               'o': 4,
#               'r': 1,
#               's': 16,
#               'y': 1},
#              'prop': {'a': 11,
#               'e': 18,
#               'h': 14,
#               'i': 8,
#               'o': 31,
#               'p': 2,
#               'r': 29,
#               's': 1,
#               'u': 2,
#               'y': 2},
#              'rope': {'a': 1, 'd': 2, 'l': 9, 'n': 2, 'r': 11, 's': 4},
#              'opel': {'e': 3, 'l': 7, 's': 1},
#              'pell': {'a': 9, 'b': 3, 'e': 16, 'i': 12, 's': 2},
#              'elle': {'a': 1,
#               'c': 7,
#               'd': 67,
#               'n': 8,
#               'q': 1,
#               'r': 40,
#               's': 6,
#               't': 2},
#              'ller': {'a': 1, 'c': 1, 'e': 2, 'g': 5, 'i': 6, 's': 37, 'y': 8},
#              '$gra': {'b': 6,
#               'c': 11,
#               'd': 23,
#               'f': 6,
#               'h': 1,
#               'i': 9,
#               'm': 11,
#               'n': 53,
#               'p': 21,
#               's': 16,
#               't': 23,
#               'v': 31,
#               'z': 5},
#              'gran': {'a': 4,
#               'c': 3,
#               'd': 39,
#               'g': 1,
#               'i': 3,
#               'n': 3,
#               't': 16,
#               'u': 7},
#              'ranu': {'l': 7, 's': 1},
#              'anul': {'a': 4, 'e': 2, 'o': 1},
#              'nula': {'r': 3, 't': 2},
#              '$plu': {'c': 8,
#               'g': 5,
#               'm': 26,
#               'n': 11,
#               'p': 1,
#               'r': 11,
#               's': 4,
#               't': 5},
#              'pluc': {'k': 8},
#              'luck': {'e': 3, 'i': 10, 'l': 1, 's': 2, 'y': 4},
#              'ucke': {'d': 8, 'r': 6, 't': 5},
#              '$whi': {'c': 2,
#               'f': 2,
#               'l': 5,
#               'm': 9,
#               'n': 7,
#               'p': 10,
#               'r': 12,
#               's': 24,
#               't': 23,
#               'z': 3},
#              'whis': {'k': 12, 'p': 6, 't': 8},
#              'hist': {'a': 2, 'i': 11, 'l': 8, 'o': 19, 'r': 2, 's': 8},
#              'istl': {'e': 17, 'i': 3, 'y': 1},
#              'stli': {'e': 7, 'k': 1, 'n': 15},
#              'tlin': {'e': 12, 'g': 32, 'i': 1},
#              '$del': {'a': 5,
#               'e': 18,
#               'h': 1,
#               'i': 54,
#               'l': 2,
#               'p': 2,
#               't': 4,
#               'u': 12,
#               'v': 4},
#              'deli': {'a': 1,
#               'b': 10,
#               'c': 10,
#               'e': 1,
#               'g': 9,
#               'l': 1,
#               'm': 6,
#               'n': 12,
#               'o': 2,
#               'q': 2,
#               'r': 3,
#               't': 3,
#               'v': 14},
#              'eliv': {'e': 17, 'i': 1},
#              'live': {'a': 1,
#               'd': 5,
#               'l': 6,
#               'n': 8,
#               'o': 1,
#               'r': 25,
#               's': 6,
#               'w': 1},
#              'iver': {'a': 3,
#               'e': 7,
#               'g': 7,
#               'i': 10,
#               'l': 1,
#               's': 43,
#               't': 4,
#               'w': 1,
#               'y': 4},
#              'veri': {'c': 2,
#               'e': 7,
#               'f': 12,
#               'l': 1,
#               'n': 32,
#               's': 12,
#               't': 5},
#              'erin': {'a': 4,
#               'c': 2,
#               'd': 2,
#               'e': 11,
#               'f': 2,
#               'g': 287,
#               'l': 5,
#               'o': 1,
#               't': 6,
#               'v': 1},
#              '$pla': {'c': 27,
#               'g': 10,
#               'i': 16,
#               'n': 33,
#               'q': 2,
#               's': 17,
#               't': 27,
#               'u': 4,
#               'y': 28,
#               'z': 2},
#              'plat': {'e': 27, 'f': 2, 'i': 9, 'o': 4, 't': 5, 'y': 2},
#              'latt': {'e': 24, 'i': 4},
#              'atte': {'d': 11, 'l': 2, 'm': 5, 'n': 40, 'r': 75, 's': 7},
#              '$ove': {'n': 2, 'r': 304},
#              'over': {'a': 20,
#               'b': 6,
#               'c': 23,
#               'd': 19,
#               'e': 28,
#               'f': 14,
#               'g': 6,
#               'h': 19,
#               'i': 18,
#               'j': 1,
#               'k': 1,
#               'l': 28,
#               'm': 4,
#               'n': 21,
#               'o': 1,
#               'p': 23,
#               'q': 1,
#               'r': 23,
#               's': 88,
#               't': 42,
#               'u': 5,
#               'v': 4,
#               'w': 18,
#               'y': 3},
#              'vera': {'b': 9, 'c': 6, 'g': 10, 'l': 6, 'm': 1, 'n': 8, 't': 1},
#              'erac': {'h': 2, 'i': 2, 't': 21, 'y': 6},
#              'ract': {'a': 8,
#               'e': 32,
#               'i': 91,
#               'l': 1,
#               'o': 15,
#               's': 15,
#               'u': 5},
#              'acti': {'b': 1,
#               'c': 36,
#               'l': 2,
#               'n': 29,
#               'o': 68,
#               's': 5,
#               't': 8,
#               'v': 56},
#              'ctiv': {'a': 23, 'e': 123, 'i': 26, 'o': 2},
#              '$emb': {'a': 27, 'e': 19, 'i': 4, 'l': 4, 'o': 14, 'r': 19},
#              'embi': {'c': 1, 't': 4},
#              'mbit': {'i': 6, 's': 1, 't': 4},
#              'bitt': {'e': 13, 'i': 1, 's': 1, 'y': 1},
#              'itte': {'d': 26, 'e': 4, 'n': 17, 'r': 60, 's': 1},
#              'tter': {'a': 4,
#               'b': 3,
#               'c': 2,
#               'e': 44,
#               'f': 3,
#               'h': 2,
#               'i': 40,
#               'l': 2,
#               'm': 5,
#               'n': 7,
#               'o': 1,
#               'p': 2,
#               's': 60,
#               'w': 1,
#               'y': 9},
#              'term': {'a': 8, 'e': 12, 'i': 72, 'l': 1, 'o': 3, 's': 1},
#              'erme': {'a': 10, 'd': 6, 'l': 1, 'n': 27, 't': 2},
#              'rmen': {'e': 2, 'i': 1, 't': 31},
#              '$eir': {'e': 1},
#              '$ten': {'a': 11,
#               'c': 1,
#               'd': 19,
#               'e': 4,
#               'f': 1,
#               'n': 2,
#               'o': 3,
#               's': 17,
#               't': 11,
#               'u': 5},
#              'tena': {'b': 4, 'c': 3, 'n': 16, 'r': 5, 't': 7},
#              'enac': {'e': 3, 'i': 5, 't': 6},
#              'naci': {'e': 1, 'n': 2, 'o': 6, 't': 3},
#              'acio': {'l': 4, 'u': 30},
#              'ciou': {'s': 89},
#              'ious': {'l': 98, 'n': 44},
#              'ousl': {'e': 2, 'y': 238},
#              '$see': {'a': 1,
#               'd': 12,
#               'i': 2,
#               'k': 5,
#               'm': 8,
#               'n': 1,
#               'p': 5,
#               'r': 2,
#               's': 3,
#               't': 5},
#              'seep': {'a': 1, 'e': 1, 'i': 1, 's': 1},
#              'eepa': {'b': 1, 'g': 1},
#              'epag': {'e': 1},
#              '$lun': {'a': 7, 'c': 10, 'e': 1, 'g': 9},
#              'lunc': {'h': 10},
#              'unch': {'a': 18,
#               'b': 3,
#               'c': 1,
#               'e': 31,
#               'i': 11,
#               'l': 3,
#               'n': 1,
#               'p': 1,
#               'r': 3,
#               't': 2,
#               'y': 3},
#              'nche': {'c': 2, 'd': 23, 'e': 1, 'o': 4, 'r': 16, 's': 28},
#              '$blu': {'b': 3,
#               'd': 4,
#               'e': 20,
#               'f': 6,
#               'i': 1,
#               'n': 14,
#               'r': 11,
#               's': 12},
#              'blun': {'a': 1, 'd': 6, 't': 8},
#              'lunt': {'a': 4, 'e': 7, 'i': 1, 'l': 1, 'n': 1, 's': 1},
#              'unte': {'d': 28,
#               'e': 4,
#               'm': 1,
#               'n': 7,
#               'o': 1,
#               'r': 62,
#               's': 5,
#               't': 1,
#               'x': 1},
#              '$rou': {'b': 2, 'g': 17, 'l': 1, 'n': 17, 's': 4, 't': 12},
#              '$cos': {'i': 6, 'm': 16, 's': 4, 't': 22, 'y': 1},
#              'cosm': {'e': 2, 'i': 4, 'o': 11},
#              'osmo': {'l': 6, 'n': 2, 'p': 2, 's': 2, 't': 1},
#              '$ush': {'e': 5},
#              'ushe': {'d': 11, 'l': 2, 'r': 15, 's': 16},
#              'sher': {'b': 1,
#               'd': 2,
#               'e': 2,
#               'i': 3,
#               'l': 1,
#               'm': 2,
#               'r': 2,
#               's': 21,
#               'w': 2,
#               'y': 2},
#              'here': {'a': 8,
#               'b': 3,
#               'd': 25,
#               'e': 1,
#               'f': 5,
#               'i': 4,
#               'n': 13,
#               'o': 5,
#               'r': 6,
#               's': 9,
#               't': 8,
#               'u': 4,
#               'v': 1,
#               'w': 4},
#              'eret': {'i': 3, 'o': 4, 'r': 1, 's': 1, 't': 4},
#              'rett': {'a': 3, 'e': 12, 'i': 10, 'o': 3, 'y': 1},
#              '$pic': {'a': 2, 'c': 1, 'k': 24, 'n': 5, 'o': 1, 't': 13},
#              'pick': {'a': 2, 'e': 11, 'i': 4, 'l': 4, 'p': 3, 's': 3, 'u': 2},
#              'icke': {'d': 22, 'l': 1, 'n': 22, 'r': 29, 's': 4, 't': 22},
#              'cket': {'b': 1,
#               'e': 9,
#               'f': 3,
#               'i': 7,
#               'k': 3,
#               'r': 1,
#               's': 18,
#               'y': 1},
#              '$lim': {'a': 1, 'b': 7, 'e': 9, 'i': 11, 'o': 4, 'p': 8},
#              'limo': {'n': 1, 'u': 3},
#              'imou': {'s': 7},
#              'mous': {'e': 6, 'i': 3, 'l': 12, 's': 3, 't': 3, 'y': 1},
#              'ousi': {'e': 2, 'l': 1, 'n': 15},
#              'usin': {'e': 9, 'g': 35, 'l': 1, 's': 1},
#              '$god': {'c': 1,
#               'd': 2,
#               'f': 3,
#               'h': 1,
#               'l': 6,
#               'm': 2,
#               'p': 1,
#               's': 4},
#              'godd': {'e': 2},
#              'odde': {'d': 5, 'n': 4, 'r': 4, 's': 3},
#              'ddes': {'s': 2, 't': 5},
#              'dess': {'e': 4, 'i': 2},
#              'esse': {'d': 53,
#               'e': 3,
#               'l': 5,
#               'n': 22,
#               'r': 8,
#               's': 72,
#               't': 1},
#              '$yea': {'h': 1, 'n': 1, 'r': 14, 's': 4},
#              'yeas': {'t': 3},
#              '$abd': {'i': 5, 'o': 3, 'u': 8},
#              'abdu': {'c': 8},
#              'bduc': {'t': 10},
#              'duct': {'a': 2, 'e': 6, 'i': 54, 'o': 11, 'r': 1, 's': 9},
#              'ucte': {'d': 14},
#              '$ins': {'a': 8,
#               'c': 8,
#               'e': 27,
#               'h': 1,
#               'i': 31,
#               'o': 14,
#               'p': 17,
#               't': 82,
#               'u': 42},
#              'nsti': {'c': 1,
#               'g': 6,
#               'l': 7,
#               'm': 1,
#               'n': 7,
#               'p': 2,
#               'r': 1,
#               't': 38},
#              'stig': {'a': 21, 'e': 3, 'i': 2, 'm': 9},
#              'tiga': {'b': 1, 'n': 2, 't': 31},
#              'igat': {'e': 28, 'i': 22, 'o': 12, 'u': 4},
#              'gati': {'n': 22, 'o': 47, 'v': 15},
#              '$inc': {'a': 29,
#               'e': 15,
#               'h': 5,
#               'i': 29,
#               'l': 17,
#               'o': 81,
#               'r': 22,
#               'u': 23},
#              'inca': {'l': 2, 'n': 8, 'p': 8, 'r': 13, 's': 2, 'u': 2},
#              'ncan': {'c': 1, 'd': 3, 'n': 2, 't': 4},
#              'cant': {'a': 7,
#               'e': 11,
#               'h': 2,
#               'i': 11,
#               'l': 3,
#               'o': 3,
#               's': 8,
#               'y': 1},
#              'anta': {'b': 4,
#               'c': 2,
#               'g': 20,
#               'i': 3,
#               'l': 8,
#               'm': 3,
#               'n': 3,
#               's': 3,
#               't': 9},
#              'ntat': {'a': 1, 'e': 9, 'h': 2, 'i': 57, 'o': 4},
#              'atio': {'c': 1, 'n': 1524, 's': 1, 'u': 6},
#              'tion': {'a': 276,
#               'e': 54,
#               'h': 1,
#               'i': 82,
#               'l': 7,
#               'm': 2,
#               'n': 2,
#               's': 680,
#               'w': 1},
#              '$hel': {'d': 1,
#               'e': 1,
#               'i': 12,
#               'l': 8,
#               'm': 6,
#               'o': 1,
#               'p': 16,
#               's': 1,
#               't': 1},
#              'help': {'e': 2, 'f': 5, 'i': 2, 'l': 5, 'm': 2, 's': 1},
#              '$enc': {'a': 16,
#               'e': 2,
#               'h': 11,
#               'i': 7,
#               'l': 9,
#               'o': 26,
#               'r': 14,
#               'u': 5,
#               'y': 7},
#              'ench': {'a': 16, 'e': 21, 'i': 8, 'm': 7},
#              'ncha': {'b': 2, 'i': 4, 'l': 5, 'n': 17, 'p': 1, 'r': 8},
#              'chan': {'c': 18, 'd': 6, 'g': 32, 'i': 19, 'n': 5, 't': 29},
#              'hant': {'a': 3,
#               'e': 7,
#               'i': 9,
#               'l': 2,
#               'm': 5,
#               'o': 2,
#               'r': 3,
#               's': 5,
#               'y': 1},
#              'antm': {'a': 1, 'e': 4},
#              'ntme': {'n': 14},
#              'tmen': {'o': 2, 't': 62},
#              'ment': {'a': 114,
#               'e': 35,
#               'h': 1,
#               'i': 28,
#               'l': 1,
#               'o': 6,
#               's': 176,
#               'u': 1},
#              '$sub': {'a': 4,
#               'b': 2,
#               'c': 18,
#               'd': 12,
#               'e': 2,
#               'f': 1,
#               'g': 2,
#               'h': 3,
#               'j': 14,
#               'l': 13,
#               'm': 21,
#               'n': 1,
#               'o': 6,
#               'p': 6,
#               'r': 2,
#               's': 76,
#               't': 32,
#               'u': 7,
#               'v': 10,
#               'w': 2,
#               'z': 1},
#              'suba': {'l': 2, 'r': 1, 't': 1},
#              'ubal': {'t': 2},
#              'balt': {'e': 2, 'i': 1},
#              'alte': {'d': 5, 'r': 39, 's': 1},
#              'lter': {'a': 12,
#               'c': 3,
#               'e': 12,
#               'g': 2,
#               'i': 8,
#               'n': 14,
#               'o': 1,
#               's': 10,
#               'w': 1,
#               'y': 2},
#              'tern': {'a': 48,
#               'e': 10,
#               'i': 13,
#               'l': 1,
#               'm': 4,
#               'n': 1,
#               'o': 3,
#               's': 9,
#               'u': 2},
#              '$wil': {'d': 17,
#               'e': 2,
#               'f': 3,
#               'i': 2,
#               'l': 11,
#               't': 4,
#               'y': 1},
#              '$ras': {'c': 3, 'e': 1, 'h': 7, 'i': 1, 'p': 8, 't': 2},
#              'rasp': {'b': 2, 'e': 4, 'i': 2, 's': 2, 'y': 1},
#              'aspe': {'c': 2, 'd': 5, 'r': 12},
#              '$elb': {'e': 1, 'o': 3},
#              'elbo': {'w': 3},
#              '$liq': {'u': 24},
#              'liqu': {'a': 2, 'e': 14, 'i': 17, 'o': 6},
#              'iqui': {'d': 15, 'f': 1, 't': 6},
#              'quid': {'a': 7, 'i': 6, 's': 3},
#              '$bam': {'b': 6},
#              'bamb': {'i': 1, 'o': 5},
#              'ambo': {'a': 2,
#               'd': 1,
#               'k': 1,
#               'l': 3,
#               'o': 5,
#               'r': 1,
#               'u': 2,
#               'y': 3},
#              'mboo': {'s': 1, 't': 1, 'z': 3},
#              '$fel': {'d': 2, 'i': 8, 'l': 10, 'o': 4, 't': 2},
#              'feli': {'c': 10, 'k': 1, 'n': 4},
#              'elin': {'e': 34, 'g': 19, 'k': 3, 'q': 7, 's': 1},
#              'line': {'a': 19,
#               'd': 14,
#               'f': 1,
#               'm': 2,
#               'n': 3,
#               'o': 2,
#               'r': 12,
#               's': 72,
#               'u': 2},
#              '$clu': {'b': 8, 'c': 4, 'e': 5, 'm': 11, 'n': 1, 's': 4, 't': 8},
#              'clum': {'b': 1, 'p': 5, 's': 5},
#              'lums': {'i': 4, 'y': 1},
#              'pans': {'e': 2, 'i': 10, 'y': 1},
#              'ansi': {'b': 1,
#               'e': 5,
#               'g': 2,
#               'n': 1,
#               'o': 8,
#               's': 3,
#               't': 11,
#               'v': 3,
#               'z': 1},
#              'nsie': {'n': 4, 's': 1, 'u': 1},
#              '$unc': {'a': 11,
#               'e': 9,
#               'h': 22,
#               'i': 3,
#               'l': 23,
#               'o': 89,
#               'r': 12,
#               't': 3,
#               'u': 5},
#              'uncr': {'a': 1, 'e': 5, 'i': 1, 'o': 5, 'u': 1},
#              'ncro': {'a': 5, 's': 3, 'w': 2},
#              'cros': {'a': 1, 'c': 8, 'e': 3, 'i': 3, 's': 53, 't': 2, 'u': 1},
#              '$dis': {'a': 86,
#               'b': 16,
#               'c': 148,
#               'd': 5,
#               'e': 32,
#               'f': 8,
#               'g': 21,
#               'h': 22,
#               'i': 32,
#               'j': 9,
#               'k': 2,
#               'l': 15,
#               'm': 28,
#               'o': 22,
#               'p': 97,
#               'q': 10,
#               'r': 22,
#               's': 61,
#               't': 89,
#               'u': 6,
#               'y': 2},
#              'disp': {'a': 16,
#               'e': 30,
#               'i': 3,
#               'l': 18,
#               'o': 26,
#               'r': 11,
#               'u': 12},
#              'ispe': {'d': 2, 'l': 4, 'n': 14, 'r': 19},
#              'spen': {'c': 1, 'd': 15, 's': 17, 't': 4},
#              'pens': {'a': 17, 'e': 11, 'i': 19},
#              'ensa': {'b': 4, 'r': 2, 't': 23},
#              'nsar': {'d': 1, 'i': 1, 'y': 1},
#              'inse': {'c': 11,
#               'd': 1,
#               'e': 1,
#               'l': 2,
#               'm': 1,
#               'n': 6,
#               'p': 2,
#               'r': 8,
#               's': 1,
#               't': 3},
#              'nsen': {'e': 3, 'g': 1, 's': 14, 't': 7},
#              'sens': {'a': 9, 'e': 9, 'i': 31, 'o': 3, 'u': 9},
#              'ensi': {'b': 22,
#               'c': 4,
#               'f': 5,
#               'g': 2,
#               'l': 4,
#               'n': 7,
#               'o': 46,
#               's': 1,
#               't': 29,
#               'v': 29},
#              'nsit': {'i': 29, 'o': 4, 's': 1, 'y': 5},
#              '$cot': {'e': 2, 's': 1, 't': 5},
#              'cote': {'r': 2},
#              'oter': {'i': 4, 'm': 1, 's': 9},
#              'teri': {'a': 30,
#               'c': 8,
#               'e': 9,
#               'l': 9,
#               'm': 2,
#               'n': 90,
#               'o': 24,
#               's': 20,
#               't': 6,
#               'u': 2},
#              '$hat': {'c': 11,
#               'e': 7,
#               'f': 1,
#               'i': 1,
#               'l': 1,
#               'r': 3,
#               's': 2,
#               't': 5},
#              'hatc': {'h': 16},
#              'atch': {'a': 5,
#               'b': 4,
#               'd': 2,
#               'e': 48,
#               'f': 3,
#               'i': 30,
#               'm': 8,
#               'p': 3,
#               's': 2,
#               't': 2,
#               'u': 1,
#               'w': 6,
#               'y': 3},
#              'tche': {'d': 43, 'l': 2, 'n': 4, 'r': 30, 's': 34, 't': 5},
#              '$und': {'a': 3,
#               'e': 186,
#               'i': 26,
#               'o': 8,
#               'r': 6,
#               'u': 8,
#               'y': 1},
#              'unde': {'a': 1,
#               'c': 6,
#               'd': 36,
#               'f': 5,
#               'l': 4,
#               'm': 4,
#               'n': 2,
#               'r': 205,
#               's': 11,
#               't': 7,
#               'v': 1},
#              'ndes': {'c': 11, 'e': 3, 'i': 5, 't': 14},
#              'dese': {'c': 4, 'g': 1, 'l': 1, 'n': 1, 'r': 18},
#              'eser': {'t': 9, 'v': 30},
#              'serv': {'a': 38, 'e': 31, 'i': 28, 'o': 2},
#              'ervi': {'c': 13,
#               'd': 2,
#               'e': 13,
#               'l': 3,
#               'n': 13,
#               'o': 1,
#               's': 12,
#               't': 1,
#               'x': 1},
#              'rvin': {'g': 17},
#              '$dan': {'c': 7,
#               'd': 4,
#               'e': 2,
#               'g': 9,
#               'i': 2,
#               'k': 2,
#               't': 1,
#               'u': 1,
#               'z': 1},
#              'danc': {'e': 20, 'i': 3, 'y': 2},
#              'ance': {'a': 2,
#               'd': 20,
#               'e': 1,
#               'l': 15,
#               'm': 4,
#               'r': 19,
#               's': 73,
#               't': 2},
#              'unco': {'i': 4,
#               'l': 3,
#               'm': 23,
#               'n': 39,
#               'o': 3,
#               'r': 6,
#               'u': 7,
#               'v': 4},
#              'ncon': {'c': 7,
#               'd': 3,
#               'f': 5,
#               'g': 5,
#               'n': 1,
#               'q': 2,
#               's': 29,
#               't': 16,
#               'v': 12},
#              'cont': {'a': 26, 'e': 55, 'i': 45, 'o': 11, 'r': 98, 'u': 4},
#              'ontr': {'a': 56, 'e': 2, 'i': 19, 'o': 22},
#              'ntro': {'d': 15,
#               'i': 2,
#               'l': 12,
#               'p': 2,
#               's': 3,
#               'u': 1,
#               'v': 14},
#              'trol': {'a': 2, 'e': 1, 'l': 23, 'o': 6, 's': 2, 'u': 1, 'y': 7},
#              'roll': {'a': 6, 'c': 1, 'e': 25, 'i': 10, 's': 5},
#              'olla': {'b': 15, 'g': 3, 'n': 1, 'p': 5, 'r': 15, 't': 7},
#              'llab': {'a': 2, 'i': 7, 'l': 19, 'o': 11, 'u': 2, 'y': 2},
#              'labl': {'e': 36, 'y': 3},
#              'elic': {'a': 15, 'e': 1, 'i': 16, 'o': 2, 's': 1, 't': 6},
#              'lici': {'a': 1, 'e': 1, 'n': 4, 'o': 4, 's': 10, 't': 43},
#              'cito': {'n': 1, 'r': 4, 'u': 6},
#              'itou': {'s': 19},
#              '$unb': {'a': 9,
#               'e': 17,
#               'i': 6,
#               'l': 8,
#               'o': 10,
#               'r': 10,
#               'u': 12},
#              'unbe': {'a': 6, 'c': 1, 'd': 2, 'k': 2, 'l': 7, 'n': 3},
#              'nbel': {'i': 8, 't': 1},
#              'beli': {'a': 1, 'e': 28, 'k': 1, 's': 2, 't': 4},
#              'elie': {'d': 2, 'f': 6, 'r': 10, 's': 10, 'v': 27},
#              'liev': {'a': 6, 'e': 16, 'i': 5},
#              'ievi': {'n': 11, 's': 2},
#              'evin': {'c': 4, 'e': 1, 'g': 11},
#              '$dec': {'a': 29,
#               'e': 29,
#               'i': 34,
#               'k': 6,
#               'l': 27,
#               'o': 56,
#               'r': 29,
#               'u': 1},
#              'decr': {'e': 16, 'i': 6, 'y': 7},
#              'ecre': {'a': 13, 'c': 1, 'e': 4, 'm': 5, 'p': 2, 't': 19},
#              'crep': {'a': 3, 'e': 1, 'i': 2, 't': 1, 'u': 1},
#              'repi': {'d': 4, 'e': 2, 'n': 3, 't': 2},
#              '$per': {'a': 6,
#               'c': 47,
#               'd': 1,
#               'e': 10,
#               'f': 36,
#               'g': 2,
#               'h': 1,
#               'i': 38,
#               'j': 4,
#               'k': 8,
#               'm': 34,
#               'n': 2,
#               'o': 4,
#               'p': 23,
#               'q': 2,
#               'r': 2,
#               's': 64,
#               't': 19,
#               'u': 6,
#               'v': 16},
#              'pers': {'a': 6,
#               'c': 2,
#               'e': 28,
#               'i': 17,
#               'o': 44,
#               'p': 13,
#               't': 12,
#               'u': 12},
#              'ersp': {'a': 1, 'e': 10, 'h': 1, 'i': 9, 'o': 1},
#              'rspi': {'c': 5, 'l': 1, 'r': 4},
#              'spir': {'a': 32, 'e': 18, 'i': 27},
#              'piri': {'c': 6, 'n': 9, 't': 20},
#              'irin': {'e': 2, 'g': 38, 's': 1},
#              'uire': {'a': 1, 'd': 5, 'm': 2, 'r': 6, 's': 6},
#              '$vil': {'e': 5, 'i': 4, 'l': 10},
#              'vile': {'d': 1, 'g': 6, 'l': 2, 'n': 1, 'r': 1, 's': 1},
#              'ilen': {'c': 7, 'e': 1, 't': 4},
#              'lene': {'c': 3, 's': 26, 't': 1},
#              '$inf': {'a': 23,
#               'e': 36,
#               'i': 31,
#               'l': 44,
#               'o': 18,
#               'r': 16,
#               'u': 11},
#              'infu': {'l': 10, 'r': 5, 's': 6},
#              'nfus': {'a': 1, 'e': 9, 'i': 7, 's': 1},
#              '$shr': {'a': 2, 'e': 12, 'i': 27, 'o': 4, 'u': 11},
#              'shre': {'d': 5, 'w': 7},
#              'hrew': {'d': 5, 's': 1},
#              'rewd': {'e': 2, 'l': 1, 'n': 1, 'r': 2},
#              'ewde': {'r': 1, 's': 1},
#              'wdes': {'t': 1},
#              '$lau': {'d': 7, 'g': 9, 'n': 15, 'r': 3},
#              'laun': {'c': 8, 'd': 10, 't': 4},
#              'aunc': {'h': 17},
#              'cher': {'e': 2,
#               'i': 7,
#               'o': 6,
#               'r': 3,
#               's': 28,
#               'u': 4,
#               'y': 6,
#               'z': 2},
#              '$pak': {'i': 1},
#              'paki': {'s': 1},
#              'akis': {'h': 3, 't': 1},
#              'kist': {'a': 1, 's': 1},
#              'ista': {'b': 1,
#               'd': 2,
#               'f': 1,
#               'k': 9,
#               'l': 2,
#               'm': 2,
#               'n': 18,
#               's': 4,
#               't': 1},
#              '$tub': {'a': 2, 'b': 1, 'e': 8, 'i': 1, 's': 1, 'u': 2},
#              'tuba': {'s': 1},
#              '$tat': {'t': 8},
#              'tatt': {'e': 2, 'l': 1, 'o': 4, 'y': 1},
#              '$loo': {'k': 12, 'm': 4, 'n': 3, 'p': 7, 's': 12, 't': 5},
#              'loop': {'e': 1, 'h': 2, 'i': 1, 's': 1, 'y': 1},
#              'ooph': {'o': 2},
#              'opho': {'b': 14, 'l': 2, 'n': 19, 'r': 1, 't': 3},
#              'phol': {'d': 5, 'e': 3, 'i': 1, 'o': 10, 's': 5},
#              'hole': {'d': 2,
#               'g': 1,
#               'h': 2,
#               'i': 1,
#               'm': 1,
#               'n': 1,
#               'r': 1,
#               's': 25,
#               'w': 1},
#              '$ext': {'e': 40, 'i': 12, 'o': 12, 'r': 63},
#              'extr': {'a': 40, 'e': 11, 'i': 8, 'o': 7, 'u': 4},
#              'xtre': {'m': 11},
#              'trem': {'a': 2, 'b': 7, 'e': 6, 'i': 5, 'o': 3, 'u': 3},
#              'rema': {'c': 2,
#               'd': 1,
#               'i': 8,
#               'k': 3,
#               'l': 2,
#               'n': 6,
#               'p': 2,
#               'r': 11,
#               's': 4,
#               't': 13},
#              '$rel': {'a': 46, 'e': 22, 'i': 45, 'o': 11, 'u': 3, 'y': 2},
#              'rela': {'b': 4,
#               'i': 1,
#               'n': 3,
#               'p': 4,
#               't': 39,
#               'u': 3,
#               'x': 9,
#               'y': 4},
#              'elat': {'e': 21, 'i': 30, 'o': 3},
#              'lati': {'a': 1,
#               'c': 1,
#               'l': 3,
#               'n': 71,
#               'o': 161,
#               't': 6,
#               'v': 25},
#              'ativ': {'e': 200, 'i': 12},
#              'tivi': {'r': 1, 's': 21, 't': 40},
#              'ivis': {'a': 1, 'e': 4, 'i': 12, 'm': 9, 'o': 2, 't': 17},
#              'prox': {'i': 14, 'y': 1},
#              'roxi': {'d': 6, 'e': 1, 'm': 13},
#              'oxim': {'a': 11, 'i': 1, 'o': 1},
#              'xima': {'l': 5, 't': 9},
#              'imat': {'e': 43, 'i': 29, 'o': 8, 't': 1, 'u': 3},
#              'mate': {'d': 19, 'l': 8, 'r': 23, 's': 22, 'u': 6},
#              'atel': {'e': 3, 'i': 6, 'l': 4, 'y': 56},
#              '$cra': {'b': 3,
#               'c': 15,
#               'd': 4,
#               'f': 13,
#               'g': 3,
#               'm': 11,
#               'n': 17,
#               'p': 1,
#               's': 13,
#               't': 6,
#               'v': 9,
#               'w': 7,
#               'y': 4,
#               'z': 8},
#              'craf': {'t': 22},
#              'raft': {'e': 11, 'i': 9, 'm': 1, 's': 13, 'y': 2},
#              'afts': {'m': 5, 'p': 1},
#              'ftsm': {'a': 4, 'e': 1},
#              'tsma': {'n': 12, 'r': 1},
#              'sman': {'a': 3, 'i': 1, 'l': 1, 's': 8, 't': 4},
#              'mans': {'e': 2, 'h': 13, 'i': 3, 'l': 1},
#              'ansh': {'a': 1, 'e': 2, 'i': 19},
#              'nshi': {'e': 1, 'n': 2, 'p': 32},
#              '$tan': {'d': 2,
#               'g': 16,
#               'k': 10,
#               'n': 10,
#               's': 1,
#               't': 7,
#               'z': 1},
#              'tand': {'a': 12,
#               'b': 1,
#               'd': 1,
#               'e': 5,
#               'i': 14,
#               'p': 2,
#               'r': 1,
#               's': 8},
#              'ande': {'d': 31,
#               'e': 5,
#               'l': 7,
#               'm': 5,
#               'r': 55,
#               's': 8,
#               'u': 1},
#              '$inh': {'a': 16, 'e': 11, 'i': 9, 'o': 5, 'u': 6},
#              'inhi': {'b': 11},
#              'nhib': {'i': 11},
#              'hibi': {'a': 3, 'o': 1, 's': 1, 't': 34},
#              'ibit': {'e': 5, 'i': 18, 'o': 5, 's': 3},
#              'bite': {'d': 9, 'e': 1, 'r': 5, 's': 3},
#              '$hob': {'b': 9, 'g': 1, 'n': 2, 'o': 1, 's': 1},
#              'hobb': {'i': 2, 'l': 4, 'y': 3},
#              '$kne': {'a': 4, 'e': 11, 'l': 2, 's': 1, 'w': 1},
#              'knea': {'d': 4},
#              '$bes': {'e': 8, 'i': 5, 'm': 1, 'o': 2, 'p': 5, 't': 20},
#              'best': {'i': 6, 'k': 1, 'o': 8, 'r': 2, 's': 4},
#              '$sta': {'b': 21,
#               'c': 6,
#               'd': 2,
#               'f': 5,
#               'g': 25,
#               'i': 17,
#               'k': 6,
#               'l': 24,
#               'm': 17,
#               'n': 22,
#               'p': 8,
#               'r': 61,
#               's': 4,
#               't': 52,
#               'u': 5,
#               'v': 4,
#               'y': 5},
#              'star': {'b': 1,
#               'c': 6,
#               'd': 14,
#               'e': 4,
#               'f': 1,
#               'g': 4,
#               'i': 1,
#               'k': 5,
#               'l': 8,
#               'r': 8,
#               's': 7,
#               't': 25,
#               'v': 5},
#              'tarl': {'e': 3, 'i': 5},
#              'arli': {'a': 5, 'c': 1, 'e': 3, 'g': 1, 'k': 2, 'n': 8, 't': 1},
#              '$wiz': {'a': 3, 'e': 1},
#              'wiza': {'r': 3},
#              'izar': {'d': 5, 'r': 3},
#              'zard': {'e': 1, 'i': 1, 'l': 1, 'o': 1, 'r': 1, 's': 5},
#              'ardr': {'o': 8, 'u': 2, 'y': 1},
#              '$str': {'a': 91, 'e': 54, 'i': 57, 'o': 28, 'u': 26, 'y': 1},
#              'stri': {'a': 21,
#               'b': 20,
#               'c': 36,
#               'd': 9,
#               'e': 6,
#               'f': 2,
#               'k': 6,
#               'l': 2,
#               'n': 17,
#               'o': 5,
#               'p': 24,
#               't': 1,
#               'v': 6},
#              'trin': {'a': 11,
#               'e': 5,
#               'g': 19,
#               'i': 2,
#               'k': 2,
#               'o': 1,
#               's': 4},
#              'ring': {'b': 5,
#               'c': 2,
#               'e': 27,
#               'i': 12,
#               'l': 36,
#               'm': 1,
#               's': 47,
#               't': 1,
#               'u': 2,
#               'w': 1,
#               'y': 3},
#              'ingi': {'e': 5, 'l': 1, 'n': 19, 't': 1, 'v': 1},
#              'ngin': {'a': 2, 'e': 10, 'g': 53},
#              '$ann': {'a': 3, 'e': 11, 'i': 7, 'o': 22, 'u': 15},
#              'annu': {'a': 9, 'i': 2, 'l': 9, 'm': 1, 'n': 1},
#              'nnui': {'t': 2},
#              'nuit': {'i': 3, 's': 1, 'y': 4},
#              '$cyn': {'i': 5},
#              'cyni': {'c': 5},
#              '$mod': {'a': 3, 'e': 33, 'i': 12, 'u': 17},
#              'mode': {'l': 11, 'm': 2, 'r': 24, 's': 6},
#              'odes': {'i': 3, 't': 6},
#              'dest': {'a': 7,
#               'e': 4,
#               'i': 12,
#               'l': 1,
#               'o': 1,
#               'r': 24,
#               'y': 1},
#              '$lob': {'b': 8, 'e': 4, 'o': 5, 's': 3, 'u': 1},
#              'lobo': {'s': 1, 't': 5},
#              'obot': {'i': 2, 'o': 5, 's': 1},
#              'boto': {'m': 6},
#              'otom': {'e': 6, 'i': 5, 'o': 1, 'u': 1, 'y': 4},
#              'omis': {'a': 7, 'c': 3, 'e': 21, 'i': 11, 's': 3, 't': 10},
#              'mise': {'d': 20, 'r': 17, 's': 12},
#              '$mai': {'d': 7, 'l': 12, 'm': 5, 'n': 23, 's': 2, 'z': 2},
#              'main': {'b': 1,
#               'd': 4,
#               'e': 2,
#               'f': 2,
#               'i': 1,
#               'l': 3,
#               's': 8,
#               't': 11},
#              'aint': {'a': 12,
#               'b': 2,
#               'e': 16,
#               'h': 2,
#               'i': 16,
#               'l': 6,
#               'n': 2,
#               's': 8,
#               'w': 1,
#               'y': 4},
#              'inta': {'b': 2, 'c': 1, 'g': 3, 'i': 10, 'k': 2, 'n': 4},
#              'ntai': {'l': 7, 'n': 30},
#              'tain': {'a': 15,
#               'c': 1,
#               'e': 37,
#               'i': 16,
#               'l': 3,
#               'm': 6,
#               'o': 1,
#               's': 19,
#               't': 8},
#              'aine': {'d': 49, 'e': 7, 'r': 22, 's': 3},
#              '$pos': {'e': 7, 'h': 1, 'i': 23, 's': 20, 't': 63, 'y': 1},
#              'post': {'a': 5,
#               'b': 3,
#               'c': 3,
# ...
#               'v': 2},
#              'revi': {'a': 7,
#               'c': 2,
#               'e': 12,
#               'l': 3,
#               'o': 2,
#               's': 18,
#               't': 5,
#               'v': 12},
#              'evis': {'a': 3, 'c': 1, 'e': 11, 'h': 5, 'i': 15, 'u': 1},
#              'visi': {'b': 14, 'n': 6, 'o': 27, 't': 15, 'v': 2},
#              'isio': {'n': 43},
#              'sion': {'a': 53, 'e': 14, 'i': 28, 'l': 4, 'm': 1, 's': 106},
#              'ioni': {'a': 1, 'c': 8, 'n': 38, 's': 90},
#              'onis': {'a': 9, 'e': 29, 'h': 12, 'i': 10, 'm': 20, 't': 90},
#              'dist': {'a': 13,
#               'e': 5,
#               'i': 33,
#               'o': 8,
#               'r': 44,
#               's': 3,
#               'u': 7},
#              'istr': {'a': 36, 'e': 15, 'i': 25, 'o': 1, 'u': 12, 'y': 11},
#              'stra': {'b': 3,
#               'c': 20,
#               'd': 8,
#               'f': 3,
#               'g': 6,
#               'i': 37,
#               'l': 7,
#               'm': 1,
#               'n': 27,
#               'p': 9,
#               'r': 2,
#               's': 1,
#               't': 98,
#               'u': 1,
#               'w': 4,
#               'y': 6},
#              'trac': {'e': 20, 'h': 5, 'i': 6, 'k': 23, 't': 89},
#              '$hen': {'c': 5, 'g': 1, 'n': 1, 'p': 1, 'r': 1, 's': 1},
#              '$sla': {'b': 2,
#               'c': 13,
#               'g': 2,
#               'i': 1,
#               'k': 2,
#               'l': 2,
#               'm': 4,
#               'n': 13,
#               'p': 7,
#               's': 5,
#               't': 9,
#               'u': 8,
#               'v': 16,
#               'y': 5},
#              'slan': {'d': 12, 'g': 2, 't': 6},
#              'land': {'e': 18,
#               'f': 4,
#               'h': 3,
#               'i': 8,
#               'l': 7,
#               'm': 5,
#               'n': 1,
#               'o': 3,
#               's': 33,
#               'u': 1,
#               'w': 1},
#              'nder': {'a': 8,
#               'b': 6,
#               'c': 16,
#               'd': 5,
#               'e': 41,
#               'f': 12,
#               'g': 13,
#               'h': 1,
#               'i': 25,
#               'k': 1,
#               'l': 18,
#               'm': 6,
#               'n': 5,
#               'o': 4,
#               'p': 21,
#               'r': 2,
#               's': 100,
#               't': 9,
#               'u': 1,
#               'v': 3,
#               'w': 13,
#               'y': 2},
#              'deri': {'d': 5, 'e': 2, 'n': 42, 's': 3, 'v': 10},
#              '$rur': {'a': 3},
#              'rura': {'l': 3},
#              'ural': {'g': 1, 'i': 23, 'l': 14, 'n': 1, 's': 2},
#              'rall': {'a': 2, 'e': 12, 'i': 4, 'o': 1, 's': 2, 'y': 37},
#              '$coi': {'f': 1, 'l': 4, 'n': 16, 't': 2},
#              'coit': {'a': 1, 'u': 1},
#              'oitu': {'s': 1},
#              '$apa': {'c': 3, 'r': 4, 't': 3},
#              'apac': {'e': 2, 'h': 2, 'i': 16, 'y': 1},
#              'pach': {'e': 2, 'y': 1},
#              'ache': {'a': 2,
#               'd': 21,
#               'l': 2,
#               'o': 2,
#               'r': 13,
#               's': 28,
#               't': 5},
#              '$bat': {'c': 4,
#               'e': 3,
#               'h': 18,
#               'i': 3,
#               'm': 2,
#               'o': 2,
#               's': 3,
#               't': 32},
#              'batt': {'a': 2, 'e': 10, 'i': 1, 'l': 20, 'o': 2, 'y': 1},
#              'attl': {'e': 32, 'i': 3},
#              '$gre': {'a': 24,
#               'c': 1,
#               'e': 40,
#               'g': 3,
#               'm': 2,
#               'n': 4,
#               'w': 1,
#               'y': 10},
#              'grey': {'b': 1, 'e': 3, 'h': 2, 'i': 2, 'n': 1, 's': 1},
#              'reyb': {'e': 1},
#              'eybe': {'a': 1, 'e': 1},
#              'ybea': {'n': 2, 'r': 1},
#              'bear': {'a': 5, 'd': 5, 'e': 5, 'i': 8, 's': 6},
#              'subs': {'c': 11,
#               'e': 8,
#               'i': 20,
#               'o': 2,
#               'p': 3,
#               't': 31,
#               'u': 5,
#               'y': 2},
#              'ubsc': {'r': 11},
#              'bscr': {'e': 2, 'i': 11},
#              'scri': {'b': 51, 'm': 16, 'p': 53},
#              'crip': {'p': 5, 't': 53},
#              'ript': {'e': 3, 'i': 25, 'o': 3, 's': 8, 'u': 3, 'w': 3, 'y': 1},
#              '$siz': {'e': 4, 'i': 1, 'z': 4},
#              '$sup': {'e': 105, 'i': 1, 'p': 56, 'r': 8, 's': 1},
#              'supp': {'e': 3, 'i': 1, 'l': 28, 'o': 27, 'r': 12, 'u': 1},
#              'uppl': {'a': 3, 'e': 9, 'i': 12, 'y': 4},
#              'ppli': {'a': 4, 'c': 18, 'e': 8, 'n': 6},
#              'plia': {'b': 1, 'n': 7},
#              'lian': {'c': 9, 's': 3, 't': 10},
#              'iant': {'e': 1, 'i': 1, 'k': 2, 'l': 5, 's': 6},
#              '$tur': {'b': 13,
#               'e': 2,
#               'f': 4,
#               'g': 3,
#               'i': 1,
#               'k': 5,
#               'm': 3,
#               'n': 23,
#               'p': 2,
#               'q': 1,
#               'r': 3,
#               't': 3},
#              'turn': {'a': 6,
#               'c': 2,
#               'e': 10,
#               'i': 7,
#               'k': 1,
#               'o': 4,
#               'p': 1,
#               'r': 1,
#               's': 6,
#               't': 2},
#              'urno': {'u': 2, 'v': 2},
#              'rnou': {'r': 2, 's': 1, 't': 2},
#              '$unm': {'a': 18, 'e': 11, 'i': 7, 'n': 1, 'o': 8, 'u': 4},
#              'unmi': {'s': 5, 't': 1, 'x': 1},
#              'nmis': {'s': 1, 't': 4},
#              'mist': {'a': 9,
#               'e': 3,
#               'i': 16,
#               'l': 1,
#               'o': 1,
#               'r': 25,
#               's': 18,
#               'y': 6},
#              'stak': {'a': 2, 'e': 12, 'i': 4},
#              'take': {'a': 5, 'd': 1, 'h': 2, 'n': 8, 'o': 2, 'r': 10, 's': 8},
#              'akea': {'b': 5, 'w': 2},
#              'keab': {'i': 1, 'l': 7},
#              'eabl': {'e': 59, 'y': 8},
#              '$vul': {'c': 5, 'g': 5, 'n': 2, 'p': 1, 't': 2, 'v': 1},
#              'vulv': {'a': 1},
#              '$umb': {'i': 2, 'r': 7},
#              'umbr': {'a': 11, 'e': 2, 'i': 1},
#              'mbre': {'l': 3, 'n': 1, 'r': 1},
#              'brel': {'l': 2, 'y': 1},
#              'rell': {'a': 2, 'e': 4, 'i': 4},
#              'ella': {'b': 4, 'c': 1, 'd': 2, 'n': 8, 'r': 4, 's': 1, 't': 19},
#              'nsta': {'b': 7,
#               'c': 3,
#               'g': 1,
#               'i': 2,
#               'k': 2,
#               'l': 16,
#               'm': 1,
#               'n': 21,
#               't': 7,
#               'y': 2},
#              'stan': {'b': 1,
#               'c': 21,
#               'd': 51,
#               'e': 2,
#               'g': 2,
#               'k': 1,
#               's': 1,
#               't': 44,
#               'z': 2},
#              'tant': {'a': 7, 'e': 4, 'i': 22, 'l': 14, 'r': 2, 's': 20},
#              'anti': {'a': 22,
#               'b': 4,
#               'c': 40,
#               'd': 5,
#               'e': 5,
#               'f': 11,
#               'g': 3,
#               'h': 1,
#               'l': 9,
#               'm': 3,
#               'n': 25,
#               'o': 1,
#               'p': 5,
#               'q': 10,
#               's': 16,
#               't': 10,
#               'v': 4},
#              'ntia': {'b': 3,
#               'g': 1,
#               'i': 1,
#               'l': 68,
#               'n': 1,
#               'r': 2,
#               's': 1,
#               't': 22},
#              'tiat': {'e': 30, 'i': 25, 'o': 6},
#              '$qua': {'c': 5,
#               'd': 25,
#               'f': 3,
#               'g': 4,
#               'i': 7,
#               'k': 6,
#               'l': 14,
#               'n': 15,
#               'r': 34,
#               's': 7,
#               't': 5,
#               'v': 4,
#               'y': 2},
#              'quar': {'a': 2,
#               'e': 6,
#               'i': 10,
#               'k': 2,
#               'r': 10,
#               't': 23,
#               'y': 2},
#              'uark': {'s': 1},
#              '$imp': {'a': 35,
#               'e': 73,
#               'i': 11,
#               'l': 41,
#               'o': 46,
#               'r': 73,
#               's': 1,
#               'u': 22},
#              'impr': {'a': 6, 'e': 29, 'i': 10, 'o': 28, 'u': 3},
#              'mpri': {'m': 1, 'n': 4, 's': 8},
#              'pris': {'a': 2,
#               'e': 15,
#               'i': 10,
#               'm': 3,
#               'o': 9,
#               's': 1,
#               't': 1},
#              'riso': {'m': 2, 'n': 15, 'r': 1, 't': 1},
#              'ison': {'e': 11, 'i': 3, 'm': 2, 'o': 1, 's': 8},
#              'sonm': {'e': 2},
#              'onme': {'n': 13},
#              'nmen': {'t': 45},
#              '$ang': {'e': 9, 'i': 3, 'l': 9, 'o': 5, 'r': 4, 's': 2, 'u': 5},
#              'ango': {'g': 1, 'l': 4, 'r': 2, 'u': 1, 'v': 2},
#              'ngol': {'a': 3, 'i': 1, 's': 1},
#              'gola': {'n': 2, 's': 1},
#              '$abs': {'c': 10, 'e': 16, 'o': 25, 't': 23, 'u': 6},
#              'abst': {'a': 6, 'e': 5, 'i': 2, 'r': 10},
#              'bstr': {'a': 12, 'e': 1, 'u': 16},
#              'ctin': {'g': 96, 'i': 2},
#              '$raz': {'e': 3, 'i': 1, 'o': 6, 'z': 1},
#              'raze': {'d': 3, 'n': 4, 'r': 1, 's': 3},
#              '$sea': {'b': 5,
#               'c': 2,
#               'f': 5,
#               'g': 5,
#               'l': 9,
#               'm': 12,
#               'n': 2,
#               'p': 4,
#               'r': 13,
#               's': 19,
#               't': 6,
#               'w': 6},
#              'seas': {'c': 2, 'e': 3, 'h': 3, 'i': 3, 'o': 13},
#              'easo': {'n': 31},
#              'ason': {'a': 14, 'e': 6, 'i': 6, 'l': 1, 'o': 1, 'r': 2, 's': 5},
#              'sona': {'b': 11,
#               'e': 1,
#               'g': 2,
#               'l': 18,
#               'n': 12,
#               'r': 2,
#               't': 16},
#              '$fak': {'e': 5, 'i': 1},
#              'fake': {'d': 1, 'r': 2, 's': 1},
#              '$fol': {'d': 6, 'i': 4, 'k': 7, 'l': 13},
#              '$spr': {'a': 17, 'e': 9, 'i': 33, 'o': 6, 'u': 4, 'y': 1},
#              'spru': {'c': 3, 'd': 2, 'n': 1},
#              'pruc': {'e': 2, 'i': 1},
#              'ruci': {'a': 6, 'b': 2, 'f': 9, 'n': 1},
#              'ucin': {'a': 6, 'e': 2, 'g': 11},
#              'clos': {'a': 1, 'e': 25, 'i': 4, 'u': 7},
#              'lose': {'d': 7,
#               'k': 1,
#               'l': 1,
#               'n': 1,
#               'r': 4,
#               's': 5,
#               't': 3,
#               'u': 2},
#              '$ant': {'a': 11,
#               'e': 18,
#               'h': 22,
#               'i': 62,
#               'l': 4,
#               'o': 2,
#               'r': 2,
#               's': 1,
#               'w': 1},
#              'antr': {'a': 5, 'e': 1, 'i': 5, 'u': 3, 'y': 12},
#              'ntru': {'d': 6, 'e': 1, 'm': 3, 's': 11, 't': 4},
#              '$dar': {'e': 4, 'i': 2, 'k': 12, 'l': 2, 'n': 4, 't': 8, 'w': 1},
#              'dart': {'b': 2, 'e': 3, 'i': 1, 's': 1},
#              'artb': {'e': 2, 'o': 2, 'r': 4, 'u': 1},
#              'rtbo': {'a': 2},
#              'tboa': {'r': 4},
#              'boar': {'d': 65, 's': 1},
#              'oard': {'e': 6, 'g': 1, 'i': 5, 'r': 1, 's': 21},
#              '$pol': {'a': 9,
#               'd': 1,
#               'e': 13,
#               'i': 39,
#               'k': 2,
#               'l': 25,
#               'o': 6,
#               't': 3,
#               'y': 62},
#              'pola': {'n': 1, 'r': 13, 's': 1, 't': 12},
#              'olar': {'i': 13, 'l': 1, 's': 4, 'y': 1},
#              'lari': {'a': 3,
#               'e': 7,
#               'f': 6,
#               'n': 9,
#               'o': 3,
#               's': 30,
#               't': 26,
#               'u': 1},
#              'aris': {'a': 13,
#               'e': 27,
#               'h': 8,
#               'i': 8,
#               'm': 12,
#               'o': 4,
#               't': 17},
#              'risa': {'b': 1, 'l': 2, 't': 36},
#              'isat': {'i': 187, 'o': 1},
#              'sati': {'a': 5,
#               'l': 2,
#               'n': 7,
#               'o': 215,
#               'r': 11,
#               's': 22,
#               'v': 2},
#              '$bur': {'b': 4,
#               'd': 6,
#               'e': 11,
#               'g': 16,
#               'i': 4,
#               'l': 5,
#               'm': 2,
#               'n': 10,
#               'p': 4,
#               'r': 5,
#               's': 9,
#               'u': 1,
#               'y': 1},
#              'buri': {'a': 3, 'e': 4},
#              'urie': {'d': 3, 'n': 2, 'r': 4, 's': 9},
#              '$gna': {'r': 3, 's': 4, 't': 2, 'w': 6},
#              'gnar': {'l': 3},
#              'narl': {'e': 1, 'i': 2, 's': 1},
#              'rlin': {'e': 17, 'g': 20, 'i': 2, 'k': 1, 's': 1},
#              'exti': {'l': 2, 'n': 11, 'r': 2},
#              'xtin': {'c': 3, 'g': 8},
#              'ting': {'a': 3,
#               'e': 11,
#               'i': 3,
#               'l': 61,
#               'r': 1,
#               's': 47,
#               'u': 17,
#               'y': 1},
#              'ingu': {'a': 9, 'e': 2, 'i': 31, 'l': 6, 's': 1},
#              'ngui': {'d': 3, 'n': 6, 's': 38},
#              'guis': {'e': 7, 'h': 27, 'i': 1, 't': 14},
#              'uish': {'a': 5, 'e': 15, 'i': 5, 'l': 1, 'm': 1, 'n': 1},
#              'ishe': {'a': 6, 'd': 60, 'r': 19, 's': 38},
#              'prof': {'a': 7,
#               'e': 18,
#               'f': 4,
#               'i': 22,
#               'l': 3,
#               'o': 6,
#               'u': 5},
#              'rofo': {'i': 4, 'r': 5, 'u': 4},
#              'ofor': {'e': 1, 'm': 5, 't': 1},
#              'form': {'a': 65,
#               'e': 32,
#               'i': 25,
#               'l': 3,
#               'o': 2,
#               's': 13,
#               'u': 18},
#              '$apr': {'i': 4, 'o': 3},
#              'apro': {'n': 2, 'o': 1, 'p': 1},
#              'ropo': {'c': 1,
#               'd': 6,
#               'g': 2,
#               'i': 1,
#               'l': 8,
#               'm': 4,
#               'n': 3,
#               'p': 1,
#               'r': 12,
#               's': 16,
#               'u': 5},
#              '$ine': {'b': 3,
#               'd': 1,
#               'f': 11,
#               'l': 8,
#               'p': 4,
#               'q': 5,
#               'r': 6,
#               's': 5,
#               'v': 2,
#               'x': 26},
#              'inex': {'a': 3, 'c': 2, 'h': 2, 'o': 3, 'p': 12, 't': 4},
#              'nexp': {'a': 1, 'e': 10, 'i': 1, 'l': 7, 'r': 4, 'u': 1},
#              'expl': {'a': 10, 'e': 2, 'i': 10, 'o': 35},
#              'xpli': {'c': 10},
#              'plic': {'a': 65, 'e': 6, 'i': 15},
#              'lica': {'b': 9, 'c': 3, 'l': 17, 'n': 12, 's': 2, 't': 60},
#              'icab': {'i': 7, 'l': 18, 'r': 1},
#              'cabl': {'e': 21, 'i': 1, 'y': 8},
#              'pare': {'d': 8, 'l': 3, 'n': 27, 'r': 2, 's': 4, 't': 1},
#              'aren': {'a': 2, 'c': 2, 'e': 4, 't': 26},
#              'rent': {'a': 4, 'e': 5, 'h': 9, 'i': 34, 'l': 13, 's': 13},
#              'enth': {'a': 2, 'e': 7, 'o': 3, 'r': 5, 's': 1, 'u': 13},
#              'nthe': {'a': 1,
#               'b': 1,
#               'i': 3,
#               'm': 4,
#               'o': 1,
#               'r': 3,
#               's': 16,
#               't': 8},
#              'thet': {'a': 1, 'e': 5, 'i': 40, 'o': 1, 's': 1},
#              'heti': {'c': 37, 'n': 2, 's': 5},
#              'etic': {'a': 37, 'e': 2, 'i': 11, 's': 14, 'u': 8},
#              '$gam': {'b': 13, 'e': 11, 'i': 1, 'm': 2, 'y': 1},
#              'gamb': {'i': 4, 'l': 6, 'o': 3},
#              'ambl': {'e': 29, 'i': 7},
#              'mble': {'d': 23, 'f': 2, 'm': 3, 'n': 2, 'r': 18, 's': 26},
#              'bler': {'s': 11},
#              '$rav': {'a': 4, 'e': 14, 'i': 11},
#              'rave': {'d': 7, 'l': 23, 'n': 16, 'r': 13, 's': 14, 'y': 2},
#              '$unl': {'a': 11, 'e': 9, 'i': 12, 'o': 13, 'u': 4},
#              'unlo': {'a': 4, 'c': 4, 'o': 1, 'u': 1, 'v': 4},
#              'nloa': {'d': 9},
#              'load': {'a': 1, 'e': 9, 'i': 6, 's': 13},
#              ...})

# %%
#ngramM(['_','_','_','on','_','_','_','back','_'],set()) 
hangman('whatever', ngramM, 8, False)
# Out:
# 8

# %%
outerKeys = dict()
for item in bigram.keys():
    for stuff in bigram[item]:
        try:
            outerKeys[item] += bigram[item][stuff]
        except:
            outerKeys[item] = bigram[item][stuff]
            
for item in bigram.keys():
    try:
        del bigram[item]['$']
    except:
        pass
    for stuff in bigram[item]:
        bigram[item][stuff] = (1.0*bigram[item][stuff])/outerKeys[item]


def bigramM(mask,guessed):
    currMax = 0.0
    currBi = '_'
    if len(guessed) == 0:
        #print (unig(mask,guessed))
        return unigPos(mask,guessed)
    else:
        for i,item in enumerate(mask):
            try:
                if item != '_' and mask[i+1] == '_':
                    #print('checking for:',item,mask,guessed)
                    sorted_x = sorted(bigram[item].items(), key=operator.itemgetter(1),reverse=True)
                    for thing in sorted_x:
                        if thing[1] > currMax and thing[0] not in guessed:
                            currMax = thing[1]
                            currBi = thing[0]
                            #print('currently Max',thing,item)
                            break
            except IndexError:
                pass
        #print('prediction is',currBi,'\n===\n')
        return currBi

hangman('whatevera', bigramM, 8, False)

# %%
totMist = 0
corrs = 0
for i,item in enumerate(test):
    mist = hangman(item, bigramM, 8, False)
    totMist += mist
    if mist < 8:
        corrs += 1
print (corrs,totMist)

# %%
from __future__ import print_function 

def hangman2(secret_word, guesser, max_mistakes=8, verbose=True,param=20):
    secret_word = secret_word.lower()
    mask = ['_'] * len(secret_word)
    guessed = set()
    if verbose:
        print("Starting hangman game. Target is", ' '.join(mask), 'length', len(secret_word))
    
    mistakes = 0
    while mistakes < max_mistakes:
        if verbose:
            print("You have", (max_mistakes-mistakes), "attempts remaining.")
        guess = guesser(mask, guessed,param)

        if verbose:
            print('Guess is', guess)
        if guess in guessed:
            if verbose:
                print('Already guessed this before.')
            mistakes += 1
        else:
            guessed.add(guess)
            if guess in secret_word:
                for i, c in enumerate(secret_word):
                    if c == guess:
                        mask[i] = c
                if verbose:
                    print('Good guess:', ' '.join(mask))
            else:
                if verbose:
                    print('Sorry, try again.')
                mistakes += 1
                
        if '_' not in mask:
            if verbose:
                print('Congratulations, you won.')
            return mistakes
        
    if verbose:
        print('Out of guesses. The word was', secret_word)    
    return mistakes

# %%
def ngramM(mask,guessed,paramList):
    proList = list()
    maski = '$' +  ''.join(mask) + '$'
    if len(mask) == mask.count('_'):
        return unigPos(mask,guessed)
    maskSort = sorted([item[-4:] for item in maski.split('_') if len(item)>=1 and '$'!=item[-1]],key=lambda x: len(x),reverse=True)
    for item in maskSort:
        for i in range(4):
            proAdded = 0
            try:
                if outKeys[len(item[i:])+1][item[i:]] > paramList[i]:
                    pro = sorted(ngModels[len(item[i:])+1][item[i:]].items(),key=operator.itemgetter(1),reverse=True)
                    for pros in pro:
                        if pros[0] not in guessed:
                            proList.append((pros[0],pros[1],pros[1]*1.0/outKeys[len(item[i:])+1][item[i:]],len(item[i:])+1))
                            proAdded = 1
                            break
                    if proAdded == 1:
                        break
            except (IndexError,KeyError) as e:
                pass
                
    #print(proList)
    if len(proList) == 0:
        return unigPos(mask,guessed)
    return sorted(proList, key=lambda vertex: (vertex[3], vertex[2]),reverse=True)[0][0]

# %%
maxparai = 0
maxCorr = 0


for uni in  range(1,20):
    for bi in range(1,20):
        for tri in range(1,20):
            for quad in range(1,20):
                totMist = 0
                corrs = 0
                parai = [quad,tri,bi,uni]
                for i,item in enumerate(test):
                    mist = hangman2(item, ngramM, 8, False,parai)
                    totMist += mist
                    if mist < 8:
                        corrs += 1
                if corrs > maxCorr:
                    print ('Best - ',parai,corrs,totMist)
                    maxparai = parai
                    maxCorr = corrs
# Out:
# Best -  [1, 1, 1, 1] 539 6110
# Best -  [2, 1, 1, 1] 540 6116
# Best -  [4, 1, 1, 1] 541 6125
# Best -  [6, 1, 1, 1] 542 6123
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-d12c8664aa89> in <module>()
#      11                 parai = [quad,tri,bi,uni]
#      12                 for i,item in enumerate(test):
# ---> 13                     mist = hangman2(item, ngramM, 8, False,parai)
#      14                     totMist += mist
#      15                     if mist < 8:
#
# <ipython-input-48-91e8ae58e27e> in hangman2(secret_word, guesser, max_mistakes, verbose, param)
#      12         if verbose:
#      13             print("You have", (max_mistakes-mistakes), "attempts remaining.")
# ---> 14         guess = guesser(mask, guessed,param)
#      15
#      16         if verbose:
#
# <ipython-input-60-dbb5dfa7abf5> in ngramM(mask, guessed, paramList)
#      10             try:
#      11                 if outKeys[len(item[i:])+1][item[i:]] > paramList[i]:
# ---> 12                     pro = sorted(ngModels[len(item[i:])+1][item[i:]].items(),key=operator.itemgetter(1),reverse=True)
#      13                     for pros in pro:
#      14                         if pros[0] not in guessed:
#
# KeyboardInterrupt:

# %%
def ngraInterp(mask,guessed,paramList=[0.1,0.2,0.3,0.4]):
    proList = list()
    maski = '$' +  ''.join(mask) + '$'
    if len(mask) == mask.count('_'):
        return unigPos(mask,guessed)
    maskSort = sorted([item[-4:] for item in maski.split('_') if len(item)>=1 and '$'!=item[-1]],key=lambda x: len(x),reverse=True)
    #print (maskSort)
    for item in maskSort:
        candidates = dict()
        for i in range(-1*(len(item)-1),1):
            #print(item,item[-i:],-i,len(item[-i:]))
            proAdded = 0
            try:
                pro = sorted(ngModels[len(item[-i:])+1][item[-i:]].items(),key=operator.itemgetter(1),reverse=True)
                for pros in pro:
                    if pros[0] not in guessed:
                        try:
                            candidates[pros[0]] += paramList[-i]* pros[1]*1.0/outKeys[len(item[-i:])+1][item[-i:]]
                        except:
                            candidates[pros[0]] = paramList[-i]* pros[1]*1.0/outKeys[len(item[-i:])+1][item[-i:]]
            except (IndexError,KeyError) as e:
                pass
        finMark = list(sorted(candidates.items(), key=operator.itemgetter(1),reverse=True)[0])
        finMark.append(item)
        proList.append(tuple(finMark))
                
    #print(proList)
    if len(proList) == 0:
        return unigPos(mask,guessed)
    #print(sorted(proList, key=lambda x: x[0],reverse=True)[0][0])
    return sorted(proList, key=lambda x: x[0],reverse=True)[0][0]

# %%
hangman2('whatever', ngraInterp, 8, False,[0.9,0.3,1.3,0.4])             
totMist = 0
corrs = 0
for i,item in enumerate(test):
    mist = hangman2(item, ngraInterp, 8, False,[0.3,0.5,0.7,0.9])
    totMist += mist
    if mist < 8:
        corrs += 1
print (corrs,totMist)
# Out:
# 505 6323

# %%
def kwtrial(a,**kwargs):
    print(kwargs)

# %%
kwtrial(1,mya=1,pia=2)
# Out:
# {'mya': 1, 'pia': 2}

# %%
a = range(-5,1)
for i in a:
    print(i)
# Out:
# -5
# -4
# -3
# -2
# -1
# 0
